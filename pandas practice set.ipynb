# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\ExportCSV (7).csv")
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  250 non-null    int64
#  1   Job Title           250 non-null    object
#  2   Email Address       250 non-null    object
#  3   FirstName LastName  250 non-null    object
#  4   marks               250 non-null    int64
#  5   speed               250 non-null    int64
#  6   stength             250 non-null    int64
#  7   Gender              250 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 15.8+ KB

# %%
d=df.describe()
d
# Out:
#                ID       marks       speed     stength
# count  250.000000  250.000000  250.000000  250.000000
# mean   125.500000    4.140000    3.904000    3.972000
# std     72.312977    2.628314    2.559882    2.543441
# min      1.000000    0.000000    0.000000    0.000000
# 25%     63.250000    2.000000    2.000000    2.000000
# 50%    125.500000    4.000000    4.000000    4.000000
# 75%    187.750000    7.000000    6.000000    6.000000
# max    250.000000    8.000000    8.000000    8.000000

# %%
df1=df[["ID","marks"]]
df1
# Out:
#       ID  marks
# 0      1      0
# 1      2      2
# 2      3      1
# 3      4      5
# 4      5      6
# ..   ...    ...
# 245  246      1
# 246  247      5
# 247  248      2
# 248  249      8
# 249  250      0
#
# [250 rows x 2 columns]

# %%
h=df.head(10)
h
# Out:
#    ID              Job Title                    Email Address  \
# 0   1           CNC Operator      Nathan_Farmer3609@gmail.com
# 1   2                 Doctor  Marigold_Woodcock8298@liret.org
# 2   3      Food Technologist     Joseph_Verdon3286@deons.tech
# 3   4            Electrician     Emely_Coleman2150@bauros.biz
# 4   5        Business Broker       Ciara_Parker1651@gmail.com
# 5   6       Ambulatory Nurse     Angelina_Owen9607@kideod.biz
# 6   7           CNC Operator         Aiden_Mann5166@deavo.com
# 7   8              Inspector   Hayden_Baldwin3297@womeona.net
# 8   9            Stockbroker     Ethan_Sheldon3123@elnee.tech
# 9  10  Healthcare Specialist        Logan_Pearce715@brety.org
#
#   FirstName LastName  marks  speed  stength  Gender
# 0      Nathan Farmer      0      4        7    Male
# 1  Marigold Woodcock      2      6        0  Female
# 2      Joseph Verdon      1      1        8    Male
# 3      Emely Coleman      5      2        7  Female
# ...

# %%
c=df.tail(-10)
c
# Out:
#       ID              Job Title                       Email Address  \
# 10    11                Auditor      William_Vollans4616@nickia.com
# 11    12          Web Developer     Victoria_Bingham8353@supunk.biz
# 12    13        Assistant Buyer           Vivian_King5503@acrit.org
# 13    14  Healthcare Specialist         Skylar_Hogg3190@womeona.net
# 14    15           Loan Officer       Judith_Ramsey9842@ubusive.com
# ..   ...                    ...                                 ...
# 245  246                Cashier           Stacy_Rossi7460@twace.org
# 246  247      Food Technologist           Erick_Janes4873@yahoo.com
# 247  248          Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249                Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250                 Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 10       William Vollans      4      0        1    Male
# ...

# %%
df2=df[["ID","marks","Gender"]]
df2
# Out:
#       ID  marks  Gender
# 0      1      0    Male
# 1      2      2  Female
# 2      3      1    Male
# 3      4      5  Female
# 4      5      6  Female
# ..   ...    ...     ...
# 245  246      1  Female
# 246  247      5    Male
# 247  248      2    Male
# 248  249      8  Female
# 249  250      0  Female
#
# [250 rows x 3 columns]

# %%
df=df.describe(include="all")
df
# Out:
#                 ID          Job Title                Email Address  \
# count   250.000000                250                          250
# unique         NaN                 60                          250
# top            NaN  Software Engineer  Nathan_Farmer3609@gmail.com
# freq           NaN                  9                            1
# mean    125.500000                NaN                          NaN
# std      72.312977                NaN                          NaN
# min       1.000000                NaN                          NaN
# 25%      63.250000                NaN                          NaN
# 50%     125.500000                NaN                          NaN
# 75%     187.750000                NaN                          NaN
# max     250.000000                NaN                          NaN
#
#        FirstName LastName       marks       speed     stength  Gender
# count                 250  250.000000  250.000000  250.000000     250
# ...

# %%
df1=df.describe(include="all")["ID"]
df1
# Out:
# count       8.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      134.414122
# std        89.796629
# min         1.000000
# 25%        70.047233
# 50%       125.500000
# 75%       203.312500
# max       250.000000
# Name: ID, dtype: float64

# %%
fg=df.iloc[25:100,0:5]
fg
# Out:
#      ID            Job Title                     Email Address  \
# 25   26  Associate Professor      Makena_Pearson4350@jiman.org
# 26   27            Inspector        Sasha_Owen4960@irrepsy.com
# 27   28         Chef Manager        Havana_Shaw5390@kideod.biz
# 28   29    Software Engineer  Charlize_Utterson3661@famism.biz
# 29   30     Insurance Broker     Belinda_Poulton3802@twace.org
# ..  ...                  ...                               ...
# 95   96      Project Manager        Gabriel_May4103@nickia.com
# 96   97     Ambulatory Nurse        Sarah_Hale2412@grannar.com
# 97   98              Auditor        Kieth_Warden4825@acrit.org
# 98   99      Project Manager       Gil_Thornton3163@guentu.biz
# 99  100            Paramedic      Dasha_Simmons2899@mafthy.com
#
#    FirstName LastName  marks
# 25     Makena Pearson      5
# 26         Sasha Owen      5
# 27        Havana Shaw      8
# 28  Charlize Utterson      1
# 29    Belinda Poulton      3
# ...

# %%
fg.to_csv(r"C:\Users\nikhil pal\Desktop\nikhil1.csv",index=False)

# %%
f=df.loc[df["marks"]>5]
f
# Out:
#       ID         Job Title                     Email Address  \
# 4      5   Business Broker        Ciara_Parker1651@gmail.com
# 6      7      CNC Operator          Aiden_Mann5166@deavo.com
# 7      8         Inspector    Hayden_Baldwin3297@womeona.net
# 8      9       Stockbroker      Ethan_Sheldon3123@elnee.tech
# 11    12     Web Developer   Victoria_Bingham8353@supunk.biz
# ..   ...               ...                               ...
# 238  239  Ambulatory Nurse         Carol_Walker437@sheye.org
# 240  241       Stockbroker      Marvin_Doherty8370@gmail.com
# 241  242         Treasurer        Logan_Stone2619@nimogy.biz
# 242  243    Retail Trainee  Johnathan_Dempsey1198@nanoff.biz
# 248  249           Bellman        Lynn_Heaton6452@nanoff.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 4         Ciara Parker      6      2        8  Female
# 6           Aiden Mann      6      6        2    Male
# 7       Hayden Baldwin      6      0        7    Male
# ...

# %%
c=df.loc[df["speed"]>5]
c
# Out:
#       ID          Job Title                     Email Address  \
# 1      2             Doctor   Marigold_Woodcock8298@liret.org
# 6      7       CNC Operator          Aiden_Mann5166@deavo.com
# 14    15       Loan Officer     Judith_Ramsey9842@ubusive.com
# 17    18          Webmaster         Hank_Miller1691@zorer.org
# 18    19               Cook     Harry_Roberts6903@bulaffy.com
# ..   ...                ...                               ...
# 239  240   IT Support Staff    Caitlyn_Rowlands2300@acrit.org
# 242  243     Retail Trainee  Johnathan_Dempsey1198@nanoff.biz
# 243  244             Doctor     Mackenzie_Rowe4280@eirey.tech
# 244  245          Treasurer     Stella_Stevens8774@typill.biz
# 246  247  Food Technologist         Erick_Janes4873@yahoo.com
#
#     FirstName LastName  marks  speed  stength  Gender
# 1    Marigold Woodcock      2      6        0  Female
# 6           Aiden Mann      6      6        2    Male
# 14       Judith Ramsey      7      7        6  Female
# ...

# %%
g=df.loc[df["Gender"]=="Male"]
g
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 6      7       CNC Operator            Aiden_Mann5166@deavo.com
# 7      8          Inspector      Hayden_Baldwin3297@womeona.net
# 8      9        Stockbroker        Ethan_Sheldon3123@elnee.tech
# ..   ...                ...                                 ...
# 237  238     Budget Analyst      Cedrick_Weasley3761@sveldo.biz
# 240  241        Stockbroker        Marvin_Doherty8370@gmail.com
# 242  243     Retail Trainee    Johnathan_Dempsey1198@nanoff.biz
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
#
#       FirstName LastName  marks  speed  stength Gender
# 0          Nathan Farmer      0      4        7   Male
# 2          Joseph Verdon      1      1        8   Male
# ...

# %%
fd=df.loc[df["Gender"]=="Female"]
fd
# Out:
#       ID         Job Title                       Email Address  \
# 1      2            Doctor     Marigold_Woodcock8298@liret.org
# 3      4       Electrician        Emely_Coleman2150@bauros.biz
# 4      5   Business Broker          Ciara_Parker1651@gmail.com
# 5      6  Ambulatory Nurse        Angelina_Owen9607@kideod.biz
# 11    12     Web Developer     Victoria_Bingham8353@supunk.biz
# ..   ...               ...                                 ...
# 243  244            Doctor       Mackenzie_Rowe4280@eirey.tech
# 244  245         Treasurer       Stella_Stevens8774@typill.biz
# 245  246           Cashier           Stacy_Rossi7460@twace.org
# 248  249           Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250            Banker  Ember_Richards2215@infotech44.tech
#
#     FirstName LastName  marks  speed  stength  Gender
# 1    Marigold Woodcock      2      6        0  Female
# 3        Emely Coleman      5      2        7  Female
# ...

# %%
g=df.describe(include="all")["Gender"]
g
# Out:
# count        250
# unique         2
# top       Female
# freq         133
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
# Name: Gender, dtype: object

# %%
v=df.loc[(df["marks"]>5) & (df["Gender"]=="Female")]
v
# Out:
#       ID                   Job Title                        Email Address  \
# 4      5             Business Broker           Ciara_Parker1651@gmail.com
# 11    12               Web Developer      Victoria_Bingham8353@supunk.biz
# 13    14       Healthcare Specialist          Skylar_Hogg3190@womeona.net
# 14    15                Loan Officer        Judith_Ramsey9842@ubusive.com
# 20    21                   Treasurer           Phoebe_Hill735@joiniaa.com
# 27    28                Chef Manager           Havana_Shaw5390@kideod.biz
# 30    31                     Cashier      Estrella_Vollans9199@nickia.com
# 31    32      Front Desk Coordinator         Selena_Newton6672@eirey.tech
# 35    36                     Steward           Margot_Wren5557@fuliss.net
# 39    40                Chef Manager          Kendra_Glynn6006@nickia.com
# 40    41                  Accountant         Estrella_James5144@sheye.org
# 41    42                      Doctor             Alba_Hall2107@famism.biz
# ...

# %%
s=df.loc[(df["speed"]>5) & (df["Gender"]=="Female") & (df["marks"]>5) & (df["stength"]>5)]
s
# Out:
#       ID                   Job Title                      Email Address  \
# 14    15                Loan Officer      Judith_Ramsey9842@ubusive.com
# 20    21                   Treasurer         Phoebe_Hill735@joiniaa.com
# 77    78  Call Center Representative        Lauren_Evans1946@supunk.biz
# 150  151            Mobile Developer      Logan_Appleton2462@nanoff.biz
# 172  173       Healthcare Specialist  Margaret_Radcliffe1860@mafthy.com
#
#      FirstName LastName  marks  speed  stength  Gender
# 14        Judith Ramsey      7      7        6  Female
# 20          Phoebe Hill      7      7        8  Female
# 77         Lauren Evans      7      7        7  Female
# 150      Logan Appleton      8      7        8  Female
# 172  Margaret Radcliffe      6      6        8  Female

# %%
f=df.loc[(df["speed"]<5) & (df["marks"]<5) & (df["Gender"]=="Male") & (df["stength"]<5)]
f
# Out:
#       ID            Job Title                   Email Address  \
# 10    11              Auditor  William_Vollans4616@nickia.com
# 46    47       HR Coordinator       Erick_Pratt4127@liret.org
# 49    50           Bookkeeper       Logan_Hudson76@nanoff.biz
# 67    68    Software Engineer       Gil_Roscoe2991@gompie.com
# 74    75         Loan Officer    Roger_Roscoe7909@joiniaa.com
# 82    83               Banker      Tony_Power2593@cispeto.com
# 85    86                Clerk      Liam_Sawyer3368@sveldo.biz
# 97    98              Auditor      Kieth_Warden4825@acrit.org
# 119  120  Investment  Advisor  Sebastian_Booth2285@fuliss.net
# 130  131         Chef Manager       Bob_Thomas2867@iatim.tech
# 135  136             Lecturer    Tony_Robinson8262@typill.biz
# 136  137      Business Broker    Maxwell_Young1369@supunk.biz
# 142  143           Bookkeeper    Gabriel_Umney7484@elnee.tech
# 148  149         Cash Manager      Jacob_Smith8526@eirey.tech
# ...

# %%
d=df.describe(include="all")
d
# Out:
#                 ID          Job Title                Email Address  \
# count   250.000000                250                          250
# unique         NaN                 60                          250
# top            NaN  Software Engineer  Nathan_Farmer3609@gmail.com
# freq           NaN                  9                            1
# mean    125.500000                NaN                          NaN
# std      72.312977                NaN                          NaN
# min       1.000000                NaN                          NaN
# 25%      63.250000                NaN                          NaN
# 50%     125.500000                NaN                          NaN
# 75%     187.750000                NaN                          NaN
# max     250.000000                NaN                          NaN
#
#        FirstName LastName       marks       speed     stength  Gender
# count                 250  250.000000  250.000000  250.000000     250
# ...

# %%
d=df.loc[(df["Job Title"]=="Software Engineer") & (df["Gender"]=="Female") & (df["speed"]>5)]
d
# Out:
#     ID          Job Title                    Email Address FirstName LastName  \
# 92  93  Software Engineer  Margot_Andersson9110@naiker.biz   Margot Andersson
#
#     marks  speed  stength  Gender
# 92      1      8        0  Female

# %%
df=df.loc[df['marks']>5]
df
# Out:
#       ID         Job Title                     Email Address  \
# 4      5   Business Broker        Ciara_Parker1651@gmail.com
# 6      7      CNC Operator          Aiden_Mann5166@deavo.com
# 7      8         Inspector    Hayden_Baldwin3297@womeona.net
# 8      9       Stockbroker      Ethan_Sheldon3123@elnee.tech
# 11    12     Web Developer   Victoria_Bingham8353@supunk.biz
# ..   ...               ...                               ...
# 238  239  Ambulatory Nurse         Carol_Walker437@sheye.org
# 240  241       Stockbroker      Marvin_Doherty8370@gmail.com
# 241  242         Treasurer        Logan_Stone2619@nimogy.biz
# 242  243    Retail Trainee  Johnathan_Dempsey1198@nanoff.biz
# 248  249           Bellman        Lynn_Heaton6452@nanoff.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 4         Ciara Parker      6      2        8  Female
# 6           Aiden Mann      6      6        2    Male
# 7       Hayden Baldwin      6      0        7    Male
# ...

# %%
x=df.loc[(df["speed"]>5 ) & (df["marks"]>5)]
x
# Out:
#       ID                   Job Title                      Email Address  \
# 6      7                CNC Operator           Aiden_Mann5166@deavo.com
# 14    15                Loan Officer      Judith_Ramsey9842@ubusive.com
# 17    18                   Webmaster          Hank_Miller1691@zorer.org
# 20    21                   Treasurer         Phoebe_Hill735@joiniaa.com
# 30    31                     Cashier    Estrella_Vollans9199@nickia.com
# 55    56           Software Engineer   Alexander_Egerton9770@twipet.com
# 57    58          Executive Director         Isla_Lindsay6967@yahoo.com
# 59    60         Associate Professor        Doug_Chapman6173@gembat.biz
# 60    61                 Audiologist       Phillip_Brock3215@bauros.biz
# 63    64         Investment  Advisor       Bree_Crawford5009@supunk.biz
# 69    70             Design Engineer         Maxwell_Roth4169@tonsy.org
# 75    76            Mobile Developer      Gil_Blackwall1627@irrepsy.com
# ...

# %%
c=df.loc[(df["speed"]<5) & (df["marks"]>5) & (df["Gender"]=="Female")]
c
# Out:
#       ID               Job Title                        Email Address  \
# 4      5         Business Broker           Ciara_Parker1651@gmail.com
# 13    14   Healthcare Specialist          Skylar_Hogg3190@womeona.net
# 27    28            Chef Manager           Havana_Shaw5390@kideod.biz
# 31    32  Front Desk Coordinator         Selena_Newton6672@eirey.tech
# 35    36                 Steward           Margot_Wren5557@fuliss.net
# 41    42                  Doctor             Alba_Hall2107@famism.biz
# 43    44      Production Painter           Julia_Willis7954@corti.com
# 45    46          Retail Trainee          Gina_Yarwood2212@gembat.biz
# 62    63            Loan Officer         Angelina_Power1906@vetan.org
# 64    65                 Bellman         Claire_Morley5308@gompie.com
# 73    74               Biologist            Jade_Brett2741@twipet.com
# 80    81     Investment  Advisor       Hadley_Edwards9491@joiniaa.com
# ...

# %%
x=df.loc[(df["Gender"]=="Female")& (df["marks"]>5)]
x
# Out:
#       ID                   Job Title                        Email Address  \
# 4      5             Business Broker           Ciara_Parker1651@gmail.com
# 11    12               Web Developer      Victoria_Bingham8353@supunk.biz
# 13    14       Healthcare Specialist          Skylar_Hogg3190@womeona.net
# 14    15                Loan Officer        Judith_Ramsey9842@ubusive.com
# 20    21                   Treasurer           Phoebe_Hill735@joiniaa.com
# 27    28                Chef Manager           Havana_Shaw5390@kideod.biz
# 30    31                     Cashier      Estrella_Vollans9199@nickia.com
# 31    32      Front Desk Coordinator         Selena_Newton6672@eirey.tech
# 35    36                     Steward           Margot_Wren5557@fuliss.net
# 39    40                Chef Manager          Kendra_Glynn6006@nickia.com
# 40    41                  Accountant         Estrella_James5144@sheye.org
# 41    42                      Doctor             Alba_Hall2107@famism.biz
# ...

# %%
f=df.loc[(df["Gender"]=="Male") & (df["speed"]>5) & (df["marks"]<5)]
f
# Out:
#       ID            Job Title                   Email Address  \
# 18    19                 Cook   Harry_Roberts6903@bulaffy.com
# 22    23   Executive Director     Wade_Quinton428@ubusive.com
# 37    38       Budget Analyst   Marvin_Parsons1997@ovock.tech
# 47    48     Machine Operator     Doug_Dickson8151@bungar.biz
# 50    51  Investment  Advisor       Bob_Murphy4789@sveldo.biz
# 52    53              Dentist       Johnny_Salt851@twipet.com
# 93    94          Electrician  Matthew_Funnell6803@mafthy.com
# 101  102              Auditor   Logan_Saunders8829@deons.tech
# 114  115       Retail Trainee    Rocco_Mcneill4859@nimogy.biz
# 116  117              Bellman     Hank_Nanton5017@dionrab.com
# 129  130              Bellman         Fred_Leigh281@brety.org
# 131  132           Fabricator   Roger_Henderson2925@liret.org
# 141  142            Paramedic      Harry_Collins490@vetan.org
# 153  154           Fabricator       Roger_Wild4016@hourpy.biz
# ...

# %%
g=df.loc[(df["speed"]>5) & (df["Gender"]=="Female") & (df["marks"]<5)]
g
# Out:
#       ID              Job Title                    Email Address  \
# 1      2                 Doctor  Marigold_Woodcock8298@liret.org
# 24    25     Production Painter       Mya_Vallins3260@bungar.biz
# 44    45      Food Technologist     Logan_Bayliss8869@mafthy.com
# 70    71       Mobile Developer      Karla_Morrow7944@bungar.biz
# 79    80    Associate Professor     Amelia_Notman5140@bauros.biz
# 92    93      Software Engineer  Margot_Andersson9110@naiker.biz
# 103  104                Auditor   Analise_Barrett6780@mafthy.com
# 112  113           Chef Manager      Lillian_Lyon7062@nanoff.biz
# 122  123       IT Support Staff        Hazel_Fox6598@grannar.com
# 124  125         HR Coordinator      Natalie_White1521@atink.com
# 125  126        Business Broker   Julianna_Cadman6294@gembat.biz
# 140  141  Systems Administrator       Abbey_Sloan7137@hourpy.biz
# 169  170  Laboratory Technician  Julianna_Shields7767@gompie.com
# ...

# %% [markdown]
# # ep4 sorting

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df1=df.sort_values("speed",ascending=False)
df1
# Out:
#       ID              Job Title                    Email Address  \
# 101  102                Auditor    Logan_Saunders8829@deons.tech
# 221  222            Audiologist       Camden_Rees5691@iatim.tech
# 154  155               Designer      Roger_Bowen7866@cispeto.com
# 152  153          Web Developer        Monica_Noon764@mafthy.com
# 176  177  Healthcare Specialist      Summer_Fowler6971@corti.com
# ..   ...                    ...                              ...
# 87    88       IT Support Staff     Rihanna_Poole2053@nanoff.biz
# 53    54      Software Engineer      Aiden_Dunbar1299@mafthy.com
# 205  206              Inspector        Aiden_Cork5863@guentu.biz
# 10    11                Auditor   William_Vollans4616@nickia.com
# 56    57                   Cook  Julian_Villiger5174@joiniaa.com
#
#     FirstName LastName  marks  speed  stength  Gender
# 101     Logan Saunders      2      8        8    Male
# 221        Camden Rees      4      8        6  Female
# ...

# %%
f=df.sort_values("speed")
f
# Out:
#       ID            Job Title                  Email Address  \
# 76    77              Bellman     Chris_Tailor631@fuliss.net
# 94    95                 Cook   Clint_Garner4925@bretoux.com
# 87    88     IT Support Staff   Rihanna_Poole2053@nanoff.biz
# 82    83               Banker     Tony_Power2593@cispeto.com
# 194  195      Project Manager   Mark_Oldfield2942@kideod.biz
# ..   ...                  ...                            ...
# 79    80  Associate Professor   Amelia_Notman5140@bauros.biz
# 101  102              Auditor  Logan_Saunders8829@deons.tech
# 98    99      Project Manager    Gil_Thornton3163@guentu.biz
# 121  122       Budget Analyst    Gabriel_Walsh7061@acrit.org
# 202  203   Executive Director      Ryan_Vinton9971@extex.org
#
#     FirstName LastName  marks  speed  stength  Gender
# 76        Chris Tailor      3      0        7    Male
# 94        Clint Garner      7      0        8    Male
# 87       Rihanna Poole      7      0        8  Female
# ...

# %%
g=df.sort_values("marks")
g
# Out:
#       ID            Job Title                   Email Address  \
# 0      1         CNC Operator     Nathan_Farmer3609@gmail.com
# 105  106        Web Developer      Mark_Bishop398@cispeto.com
# 116  117              Bellman     Hank_Nanton5017@dionrab.com
# 119  120  Investment  Advisor  Sebastian_Booth2285@fuliss.net
# 120  121    Software Engineer      Emely_Young1477@twipet.com
# ..   ...                  ...                             ...
# 113  114            Biologist     Liam_Bennett8055@sveldo.biz
# 213  214            Treasurer      Chad_Simmons1204@tonsy.org
# 110  111          Stockbroker       Kurt_Ebden5990@typill.biz
# 53    54    Software Engineer     Aiden_Dunbar1299@mafthy.com
# 248  249              Bellman      Lynn_Heaton6452@nanoff.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 0        Nathan Farmer      0      4        7    Male
# 105        Mark Bishop      0      0        5    Male
# 116        Hank Nanton      0      7        4    Male
# ...

# %%
d=df.sort_values(["speed","stength","marks"],ascending=[False,False,False])
d
# Out:
#       ID           Job Title                   Email Address  \
# 101  102             Auditor   Logan_Saunders8829@deons.tech
# 26    27           Inspector      Sasha_Owen4960@irrepsy.com
# 114  115      Retail Trainee    Rocco_Mcneill4859@nimogy.biz
# 44    45   Food Technologist    Logan_Bayliss8869@mafthy.com
# 202  203  Executive Director       Ryan_Vinton9971@extex.org
# ..   ...                 ...                             ...
# 82    83              Banker      Tony_Power2593@cispeto.com
# 148  149        Cash Manager      Jacob_Smith8526@eirey.tech
# 8      9         Stockbroker    Ethan_Sheldon3123@elnee.tech
# 10    11             Auditor  William_Vollans4616@nickia.com
# 74    75        Loan Officer    Roger_Roscoe7909@joiniaa.com
#
#     FirstName LastName  marks  speed  stength  Gender
# 101     Logan Saunders      2      8        8    Male
# 26          Sasha Owen      5      8        7  Female
# 114      Rocco Mcneill      4      8        7    Male
# ...

# %%
ds=df.sort_values(["speed","marks"],ascending=[True,False])
df1=ds.reset_index(drop=True)
sg=df1.to_csv(r"C:\Users\nikhil pal\Desktop\nik1.csv",index=False)

# %%
df=df.sort_values("speed")
df
# Out:
#       ID            Job Title                 Email Address  \
# 0      9          Stockbroker  Ethan_Sheldon3123@elnee.tech
# 28   163            Inspector   Logan_Button5340@gembat.biz
# 27   149         Cash Manager    Jacob_Smith8526@eirey.tech
# 26   106        Web Developer    Mark_Bishop398@cispeto.com
# 25   205              Auditor   Robyn_Hopkins5517@atink.com
# ..   ...                  ...                           ...
# 231   18            Webmaster     Hank_Miller1691@zorer.org
# 229   64  Investment  Advisor  Bree_Crawford5009@supunk.biz
# 248  113         Chef Manager   Lillian_Lyon7062@nanoff.biz
# 238  247    Food Technologist     Erick_Janes4873@yahoo.com
# 249  209               Doctor  Cherish_Young5266@supunk.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 0        Ethan Sheldon      8      0        1    Male
# 28        Logan Button      0      0        4    Male
# 27         Jacob Smith      0      0        2    Male
# ...

# %%
df=df.sort_values(["speed","marks"])
df
# Out:
#       ID            Job Title                 Email Address  \
# 28   163            Inspector   Logan_Button5340@gembat.biz
# 27   149         Cash Manager    Jacob_Smith8526@eirey.tech
# 26   106        Web Developer    Mark_Bishop398@cispeto.com
# 25   205              Auditor   Robyn_Hopkins5517@atink.com
# 24    83               Banker    Tony_Power2593@cispeto.com
# ..   ...                  ...                           ...
# 233  226              Cashier   Helen_Verdon1253@ovock.tech
# 232  153        Web Developer     Monica_Noon764@mafthy.com
# 231   18            Webmaster     Hank_Miller1691@zorer.org
# 230  122       Budget Analyst   Gabriel_Walsh7061@acrit.org
# 229   64  Investment  Advisor  Bree_Crawford5009@supunk.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 28        Logan Button      0      0        4    Male
# 27         Jacob Smith      0      0        2    Male
# 26         Mark Bishop      0      0        5    Male
# ...

# %%
df=df.sort_values("speed",ascending=False)
df
# Out:
#       ID            Job Title                    Email Address  \
# 229   64  Investment  Advisor     Bree_Crawford5009@supunk.biz
# 239   80  Associate Professor     Amelia_Notman5140@bauros.biz
# 247   93    Software Engineer  Margot_Andersson9110@naiker.biz
# 248  113         Chef Manager      Lillian_Lyon7062@nanoff.biz
# 246  217             Operator      Ethan_Connor2750@kideod.biz
# ..   ...                  ...                              ...
# 7    241          Stockbroker     Marvin_Doherty8370@gmail.com
# 0      9          Stockbroker     Ethan_Sheldon3123@elnee.tech
# 1     54    Software Engineer      Aiden_Dunbar1299@mafthy.com
# 2    165         Loan Officer     Daria_Quinton7922@typill.biz
# 28   163            Inspector      Logan_Button5340@gembat.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 229      Bree Crawford      8      8        5  Female
# 239      Amelia Notman      4      8        6  Female
# ...

# %%
g=df.sort_values(["speed","marks"],ascending=[True,False])
g
# Out:
#       ID           Job Title                    Email Address  \
# 0      9         Stockbroker     Ethan_Sheldon3123@elnee.tech
# 1     54   Software Engineer      Aiden_Dunbar1299@mafthy.com
# 2    165        Loan Officer     Daria_Quinton7922@typill.biz
# 3     88    IT Support Staff     Rihanna_Poole2053@nanoff.biz
# 4     95                Cook     Clint_Garner4925@bretoux.com
# ..   ...                 ...                              ...
# 245  203  Executive Director        Ryan_Vinton9971@extex.org
# 244  102             Auditor    Logan_Saunders8829@deons.tech
# 247   93   Software Engineer  Margot_Andersson9110@naiker.biz
# 248  113        Chef Manager      Lillian_Lyon7062@nanoff.biz
# 249  209              Doctor     Cherish_Young5266@supunk.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 0        Ethan Sheldon      8      0        1    Male
# 1         Aiden Dunbar      8      0        7    Male
# 2        Daria Quinton      8      0        7  Female
# ...

# %%
f=df.sort_values(["speed","marks"],ascending=[False,True])
f
# Out:
#       ID           Job Title                    Email Address  \
# 247   93   Software Engineer  Margot_Andersson9110@naiker.biz
# 248  113        Chef Manager      Lillian_Lyon7062@nanoff.biz
# 249  209              Doctor     Cherish_Young5266@supunk.biz
# 246  217            Operator      Ethan_Connor2750@kideod.biz
# 245  203  Executive Director        Ryan_Vinton9971@extex.org
# ..   ...                 ...                              ...
# 6    206           Inspector        Aiden_Cork5863@guentu.biz
# 7    241         Stockbroker     Marvin_Doherty8370@gmail.com
# 0      9         Stockbroker     Ethan_Sheldon3123@elnee.tech
# 1     54   Software Engineer      Aiden_Dunbar1299@mafthy.com
# 2    165        Loan Officer     Daria_Quinton7922@typill.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 247   Margot Andersson      1      8        0  Female
# 248       Lillian Lyon      1      8        2  Female
# 249      Cherish Young      1      8        5  Female
# ...

# %%
df=f.to_csv(r"C:\Users\nikhil pal\Desktop\newfile",index=False)
s=f.reset_index(drop=True)
s
# Out:
#       ID           Job Title                    Email Address  \
# 0     93   Software Engineer  Margot_Andersson9110@naiker.biz
# 1    113        Chef Manager      Lillian_Lyon7062@nanoff.biz
# 2    209              Doctor     Cherish_Young5266@supunk.biz
# 3    217            Operator      Ethan_Connor2750@kideod.biz
# 4    203  Executive Director        Ryan_Vinton9971@extex.org
# ..   ...                 ...                              ...
# 245  206           Inspector        Aiden_Cork5863@guentu.biz
# 246  241         Stockbroker     Marvin_Doherty8370@gmail.com
# 247    9         Stockbroker     Ethan_Sheldon3123@elnee.tech
# 248   54   Software Engineer      Aiden_Dunbar1299@mafthy.com
# 249  165        Loan Officer     Daria_Quinton7922@typill.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 0     Margot Andersson      1      8        0  Female
# 1         Lillian Lyon      1      8        2  Female
# 2        Cherish Young      1      8        5  Female
# ...

# %%
c=df.sort_values("speed")
c
# Out:
#       ID            Job Title                  Email Address  \
# 76    77              Bellman     Chris_Tailor631@fuliss.net
# 94    95                 Cook   Clint_Garner4925@bretoux.com
# 87    88     IT Support Staff   Rihanna_Poole2053@nanoff.biz
# 82    83               Banker     Tony_Power2593@cispeto.com
# 194  195      Project Manager   Mark_Oldfield2942@kideod.biz
# ..   ...                  ...                            ...
# 79    80  Associate Professor   Amelia_Notman5140@bauros.biz
# 101  102              Auditor  Logan_Saunders8829@deons.tech
# 98    99      Project Manager    Gil_Thornton3163@guentu.biz
# 121  122       Budget Analyst    Gabriel_Walsh7061@acrit.org
# 202  203   Executive Director      Ryan_Vinton9971@extex.org
#
#     FirstName LastName  marks  speed  stength  Gender
# 76        Chris Tailor      3      0        7    Male
# 94        Clint Garner      7      0        8    Male
# 87       Rihanna Poole      7      0        8  Female
# ...

# %%
g=c.sort_values(["speed","marks"])
g
# Out:
#       ID            Job Title                 Email Address  \
# 105  106        Web Developer    Mark_Bishop398@cispeto.com
# 148  149         Cash Manager    Jacob_Smith8526@eirey.tech
# 162  163            Inspector   Logan_Button5340@gembat.biz
# 82    83               Banker    Tony_Power2593@cispeto.com
# 204  205              Auditor   Robyn_Hopkins5517@atink.com
# ..   ...                  ...                           ...
# 17    18            Webmaster     Hank_Miller1691@zorer.org
# 152  153        Web Developer     Monica_Noon764@mafthy.com
# 225  226              Cashier   Helen_Verdon1253@ovock.tech
# 63    64  Investment  Advisor  Bree_Crawford5009@supunk.biz
# 121  122       Budget Analyst   Gabriel_Walsh7061@acrit.org
#
#     FirstName LastName  marks  speed  stength  Gender
# 105        Mark Bishop      0      0        5    Male
# 148        Jacob Smith      0      0        2    Male
# 162       Logan Button      0      0        4    Male
# ...

# %%
d=g.reset_index(drop=False)
d
# Out:
#      index   ID            Job Title                 Email Address  \
# 0      105  106        Web Developer    Mark_Bishop398@cispeto.com
# 1      148  149         Cash Manager    Jacob_Smith8526@eirey.tech
# 2      162  163            Inspector   Logan_Button5340@gembat.biz
# 3       82   83               Banker    Tony_Power2593@cispeto.com
# 4      204  205              Auditor   Robyn_Hopkins5517@atink.com
# ..     ...  ...                  ...                           ...
# 245     17   18            Webmaster     Hank_Miller1691@zorer.org
# 246    152  153        Web Developer     Monica_Noon764@mafthy.com
# 247    225  226              Cashier   Helen_Verdon1253@ovock.tech
# 248     63   64  Investment  Advisor  Bree_Crawford5009@supunk.biz
# 249    121  122       Budget Analyst   Gabriel_Walsh7061@acrit.org
#
#     FirstName LastName  marks  speed  stength  Gender
# 0          Mark Bishop      0      0        5    Male
# ...

# %%
f=d.reset_index(drop=True)
f
# Out:
#      index   ID            Job Title                 Email Address  \
# 0      105  106        Web Developer    Mark_Bishop398@cispeto.com
# 1      148  149         Cash Manager    Jacob_Smith8526@eirey.tech
# 2      162  163            Inspector   Logan_Button5340@gembat.biz
# 3       82   83               Banker    Tony_Power2593@cispeto.com
# 4      204  205              Auditor   Robyn_Hopkins5517@atink.com
# ..     ...  ...                  ...                           ...
# 245     17   18            Webmaster     Hank_Miller1691@zorer.org
# 246    152  153        Web Developer     Monica_Noon764@mafthy.com
# 247    225  226              Cashier   Helen_Verdon1253@ovock.tech
# 248     63   64  Investment  Advisor  Bree_Crawford5009@supunk.biz
# 249    121  122       Budget Analyst   Gabriel_Walsh7061@acrit.org
#
#     FirstName LastName  marks  speed  stength  Gender
# 0          Mark Bishop      0      0        5    Male
# ...

# %%
g=f.reset_index(drop=True)
g
# Out:
#      index   ID            Job Title                 Email Address  \
# 0      105  106        Web Developer    Mark_Bishop398@cispeto.com
# 1      148  149         Cash Manager    Jacob_Smith8526@eirey.tech
# 2      162  163            Inspector   Logan_Button5340@gembat.biz
# 3       82   83               Banker    Tony_Power2593@cispeto.com
# 4      204  205              Auditor   Robyn_Hopkins5517@atink.com
# ..     ...  ...                  ...                           ...
# 245     17   18            Webmaster     Hank_Miller1691@zorer.org
# 246    152  153        Web Developer     Monica_Noon764@mafthy.com
# 247    225  226              Cashier   Helen_Verdon1253@ovock.tech
# 248     63   64  Investment  Advisor  Bree_Crawford5009@supunk.biz
# 249    121  122       Budget Analyst   Gabriel_Walsh7061@acrit.org
#
#     FirstName LastName  marks  speed  stength  Gender
# 0          Mark Bishop      0      0        5    Male
# ...

# %%
c=df.sort_values(["speed","marks"],ascending=[True,False])
c
# Out:
#       ID           Job Title                    Email Address  \
# 8      9         Stockbroker     Ethan_Sheldon3123@elnee.tech
# 53    54   Software Engineer      Aiden_Dunbar1299@mafthy.com
# 164  165        Loan Officer     Daria_Quinton7922@typill.biz
# 87    88    IT Support Staff     Rihanna_Poole2053@nanoff.biz
# 94    95                Cook     Clint_Garner4925@bretoux.com
# ..   ...                 ...                              ...
# 202  203  Executive Director        Ryan_Vinton9971@extex.org
# 216  217            Operator      Ethan_Connor2750@kideod.biz
# 92    93   Software Engineer  Margot_Andersson9110@naiker.biz
# 112  113        Chef Manager      Lillian_Lyon7062@nanoff.biz
# 208  209              Doctor     Cherish_Young5266@supunk.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 8        Ethan Sheldon      8      0        1    Male
# 53        Aiden Dunbar      8      0        7    Male
# 164      Daria Quinton      8      0        7  Female
# ...

# %%
c=df.loc[(df["marks"]==8) & (df["Gender"]=="Female")] 
c
# Out:
#       ID              Job Title                   Email Address  \
# 27    28           Chef Manager      Havana_Shaw5390@kideod.biz
# 35    36                Steward      Margot_Wren5557@fuliss.net
# 40    41             Accountant    Estrella_James5144@sheye.org
# 43    44     Production Painter      Julia_Willis7954@corti.com
# 57    58     Executive Director      Isla_Lindsay6967@yahoo.com
# 63    64    Investment  Advisor    Bree_Crawford5009@supunk.biz
# 73    74              Biologist       Jade_Brett2741@twipet.com
# 86    87  Systems Administrator       Lynn_Thomas8337@qater.org
# 88    89            Electrician       Celina_Shaw7085@gmail.com
# 150  151       Mobile Developer   Logan_Appleton2462@nanoff.biz
# 151  152     Production Painter       Hope_Ellery9146@extex.org
# 164  165           Loan Officer    Daria_Quinton7922@typill.biz
# 166  167  Systems Administrator    Mayleen_Gavin6323@muall.tech
# 170  171         Budget Analyst    Carol_Funnell3000@nickia.com
# ...

# %%
f=df.loc[(df["speed"]>5) & (df["Gender"]=="Female") & (df["marks"]<5)]
f
# Out:
#       ID              Job Title                    Email Address  \
# 1      2                 Doctor  Marigold_Woodcock8298@liret.org
# 24    25     Production Painter       Mya_Vallins3260@bungar.biz
# 44    45      Food Technologist     Logan_Bayliss8869@mafthy.com
# 70    71       Mobile Developer      Karla_Morrow7944@bungar.biz
# 79    80    Associate Professor     Amelia_Notman5140@bauros.biz
# 92    93      Software Engineer  Margot_Andersson9110@naiker.biz
# 103  104                Auditor   Analise_Barrett6780@mafthy.com
# 112  113           Chef Manager      Lillian_Lyon7062@nanoff.biz
# 122  123       IT Support Staff        Hazel_Fox6598@grannar.com
# 124  125         HR Coordinator      Natalie_White1521@atink.com
# 125  126        Business Broker   Julianna_Cadman6294@gembat.biz
# 140  141  Systems Administrator       Abbey_Sloan7137@hourpy.biz
# 169  170  Laboratory Technician  Julianna_Shields7767@gompie.com
# ...

# %% [markdown]
# # ep5 indexing slicing & droping values

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
g=df.columns
list(g)
# Out:
# ['ID',
#  'Job Title',
#  'Email Address',
#  'FirstName LastName',
#  'marks',
#  'speed',
#  'stength',
#  'Gender']

# %%
df["total"]=df["marks"]+df["speed"]+df["stength"]
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  total
# 0          Nathan Farmer      0      4        7    Male     11
# 1      Marigold Woodcock      2      6        0  Female      8
# ...

# %%
df["tripal"]=df["speed"]*3
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  total  tripal
# 0          Nathan Farmer      0      4        7    Male     11      12
# ...

# %%
df=df.drop(columns="total")
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  tripal
# 0          Nathan Farmer      0      4        7    Male      12
# 1      Marigold Woodcock      2      6        0  Female      18
# ...

# %%
df["total"]=df.iloc[:,4:7].sum(axis=1)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  tripal  total
# 0          Nathan Farmer      0      4        7    Male      12     11
# ...

# %%
print(list(df.columns))
# Out:
# ['ID', 'Job Title', 'Email Address', 'FirstName LastName', 'marks', 'speed', 'stength', 'Gender', 'tripal', 'total']

# %%
e=list(df.columns)

# %%
l=e[0:2]+[e[-1]]+e[2:9]
df=df[l]
df
# Out:
#       ID          Job Title  total                       Email Address  \
# 0      1       CNC Operator     11         Nathan_Farmer3609@gmail.com
# 1      2             Doctor      8     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist     10        Joseph_Verdon3286@deons.tech
# 3      4        Electrician     14        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker     16          Ciara_Parker1651@gmail.com
# ..   ...                ...    ...                                 ...
# 245  246            Cashier      9           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist     16           Erick_Janes4873@yahoo.com
# 247  248      Web Developer     10  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman     13          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker      6  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  tripal
# ...

# %%
df1=df.sort_values('total',ascending=False)
df1
# Out:
#       ID            Job Title  total                   Email Address  \
# 150  151     Mobile Developer     23   Logan_Appleton2462@nanoff.biz
# 20    21            Treasurer     22      Phoebe_Hill735@joiniaa.com
# 59    60  Associate Professor     22     Doug_Chapman6173@gembat.biz
# 75    76     Mobile Developer     22   Gil_Blackwall1627@irrepsy.com
# 63    64  Investment  Advisor     21    Bree_Crawford5009@supunk.biz
# ..   ...                  ...    ...                             ...
# 82    83               Banker      3      Tony_Power2593@cispeto.com
# 66    67         Loan Officer      3  Callie_Appleton8542@famism.biz
# 136  137      Business Broker      3    Maxwell_Young1369@supunk.biz
# 74    75         Loan Officer      2    Roger_Roscoe7909@joiniaa.com
# 148  149         Cash Manager      2      Jacob_Smith8526@eirey.tech
#
#     FirstName LastName  marks  speed  stength  Gender  tripal
# 150     Logan Appleton      8      7        8  Female      21
# ...

# %%
r=df.head(10)
r
# Out:
#    ID              Job Title  total                    Email Address  \
# 0   1           CNC Operator     11      Nathan_Farmer3609@gmail.com
# 1   2                 Doctor      8  Marigold_Woodcock8298@liret.org
# 2   3      Food Technologist     10     Joseph_Verdon3286@deons.tech
# 3   4            Electrician     14     Emely_Coleman2150@bauros.biz
# 4   5        Business Broker     16       Ciara_Parker1651@gmail.com
# 5   6       Ambulatory Nurse     11     Angelina_Owen9607@kideod.biz
# 6   7           CNC Operator     14         Aiden_Mann5166@deavo.com
# 7   8              Inspector     13   Hayden_Baldwin3297@womeona.net
# 8   9            Stockbroker      9     Ethan_Sheldon3123@elnee.tech
# 9  10  Healthcare Specialist      9        Logan_Pearce715@brety.org
#
#   FirstName LastName  marks  speed  stength  Gender  tripal
# 0      Nathan Farmer      0      4        7    Male      12
# 1  Marigold Woodcock      2      6        0  Female      18
# ...

# %%
df=df.drop(columns=["total","tripal"])
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df1
# Out:
#       ID            Job Title  total                   Email Address  \
# 150  151     Mobile Developer     23   Logan_Appleton2462@nanoff.biz
# 20    21            Treasurer     22      Phoebe_Hill735@joiniaa.com
# 59    60  Associate Professor     22     Doug_Chapman6173@gembat.biz
# 75    76     Mobile Developer     22   Gil_Blackwall1627@irrepsy.com
# 63    64  Investment  Advisor     21    Bree_Crawford5009@supunk.biz
# ..   ...                  ...    ...                             ...
# 82    83               Banker      3      Tony_Power2593@cispeto.com
# 66    67         Loan Officer      3  Callie_Appleton8542@famism.biz
# 136  137      Business Broker      3    Maxwell_Young1369@supunk.biz
# 74    75         Loan Officer      2    Roger_Roscoe7909@joiniaa.com
# 148  149         Cash Manager      2      Jacob_Smith8526@eirey.tech
#
#     FirstName LastName  marks  speed  stength  Gender  tripal
# 150     Logan Appleton      8      7        8  Female      21
# ...

# %%
p=["total","tripal"]
f=df1.drop(columns=p)
f=df1.reset_index(drop=True)
f=df1.drop(columns=p).reset_index(drop=True)
f
# Out:
#       ID            Job Title                   Email Address  \
# 0    151     Mobile Developer   Logan_Appleton2462@nanoff.biz
# 1     21            Treasurer      Phoebe_Hill735@joiniaa.com
# 2     60  Associate Professor     Doug_Chapman6173@gembat.biz
# 3     76     Mobile Developer   Gil_Blackwall1627@irrepsy.com
# 4     64  Investment  Advisor    Bree_Crawford5009@supunk.biz
# ..   ...                  ...                             ...
# 245   83               Banker      Tony_Power2593@cispeto.com
# 246   67         Loan Officer  Callie_Appleton8542@famism.biz
# 247  137      Business Broker    Maxwell_Young1369@supunk.biz
# 248   75         Loan Officer    Roger_Roscoe7909@joiniaa.com
# 249  149         Cash Manager      Jacob_Smith8526@eirey.tech
#
#     FirstName LastName  marks  speed  stength  Gender
# 0       Logan Appleton      8      7        8  Female
# 1          Phoebe Hill      7      7        8  Female
# 2         Doug Chapman      8      6        8    Male
# ...

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df1["dc"]=(df1["total"]-5)*(5)
df1
s=df1.sort_values(["total","dc"],ascending=[True,True])
s
# Out:
#       ID                   Job Title  total                   Email Address  \
# 74    75                Loan Officer      2    Roger_Roscoe7909@joiniaa.com
# 148  149                Cash Manager      2      Jacob_Smith8526@eirey.tech
# 82    83                      Banker      3      Tony_Power2593@cispeto.com
# 66    67                Loan Officer      3  Callie_Appleton8542@famism.biz
# 136  137             Business Broker      3    Maxwell_Young1369@supunk.biz
# ..   ...                         ...    ...                             ...
# 77    78  Call Center Representative     21     Lauren_Evans1946@supunk.biz
# 20    21                   Treasurer     22      Phoebe_Hill735@joiniaa.com
# 59    60         Associate Professor     22     Doug_Chapman6173@gembat.biz
# 75    76            Mobile Developer     22   Gil_Blackwall1627@irrepsy.com
# 150  151            Mobile Developer     23   Logan_Appleton2462@nanoff.biz
#
# ...

# %%
p=["total","dc","tripal"]
f=df1.drop(columns=p).reset_index(drop=True)
f
# Out:
#       ID            Job Title                   Email Address  \
# 0    151     Mobile Developer   Logan_Appleton2462@nanoff.biz
# 1     21            Treasurer      Phoebe_Hill735@joiniaa.com
# 2     60  Associate Professor     Doug_Chapman6173@gembat.biz
# 3     76     Mobile Developer   Gil_Blackwall1627@irrepsy.com
# 4     64  Investment  Advisor    Bree_Crawford5009@supunk.biz
# ..   ...                  ...                             ...
# 245   83               Banker      Tony_Power2593@cispeto.com
# 246   67         Loan Officer  Callie_Appleton8542@famism.biz
# 247  137      Business Broker    Maxwell_Young1369@supunk.biz
# 248   75         Loan Officer    Roger_Roscoe7909@joiniaa.com
# 249  149         Cash Manager      Jacob_Smith8526@eirey.tech
#
#     FirstName LastName  marks  speed  stength  Gender
# 0       Logan Appleton      8      7        8  Female
# 1          Phoebe Hill      7      7        8  Female
# 2         Doug Chapman      8      6        8    Male
# ...

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
g=df.head(10)
g
# Out:
#    ID              Job Title                    Email Address  \
# 0   1           CNC Operator      Nathan_Farmer3609@gmail.com
# 1   2                 Doctor  Marigold_Woodcock8298@liret.org
# 2   3      Food Technologist     Joseph_Verdon3286@deons.tech
# 3   4            Electrician     Emely_Coleman2150@bauros.biz
# 4   5        Business Broker       Ciara_Parker1651@gmail.com
# 5   6       Ambulatory Nurse     Angelina_Owen9607@kideod.biz
# 6   7           CNC Operator         Aiden_Mann5166@deavo.com
# 7   8              Inspector   Hayden_Baldwin3297@womeona.net
# 8   9            Stockbroker     Ethan_Sheldon3123@elnee.tech
# 9  10  Healthcare Specialist        Logan_Pearce715@brety.org
#
#   FirstName LastName  marks  speed  stength  Gender
# 0      Nathan Farmer      0      4        7    Male
# 1  Marigold Woodcock      2      6        0  Female
# 2      Joseph Verdon      1      1        8    Male
# 3      Emely Coleman      5      2        7  Female
# ...

# %%
df["new"]=df["speed"]+df["marks"]+df["stength"]
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  new
# 0          Nathan Farmer      0      4        7    Male   11
# 1      Marigold Woodcock      2      6        0  Female    8
# ...

# %%
df=df.drop(columns=("new"))
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df["new"]=df.iloc[:,4:7].sum(axis=1)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  new
# 0          Nathan Farmer      0      4        7    Male   11
# 1      Marigold Woodcock      2      6        0  Female    8
# ...

# %%
print(list(df.columns))
# Out:
# ['ID', 'Job Title', 'Email Address', 'FirstName LastName', 'marks', 'speed', 'stength', 'Gender', 'new']

# %%
e=list(df.columns)

# %%
l=e[0:2]+[e[-2]]+[e[-1]]+e[2:-2]
dfw=df[l]
dfw
# Out:
#       ID          Job Title  Gender  new                       Email Address  \
# 0      1       CNC Operator    Male   11         Nathan_Farmer3609@gmail.com
# 1      2             Doctor  Female    8     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist    Male   10        Joseph_Verdon3286@deons.tech
# 3      4        Electrician  Female   14        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker  Female   16          Ciara_Parker1651@gmail.com
# ..   ...                ...     ...  ...                                 ...
# 245  246            Cashier  Female    9           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist    Male   16           Erick_Janes4873@yahoo.com
# 247  248      Web Developer    Male   10  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman  Female   13          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Female    6  Ember_Richards2215@infotech44.tech
#
# ...

# %%
f=df.sort_values(["new","Gender"],ascending=[True,True])
f
# Out:
#       ID                   Job Title  Gender  new  \
# 74    75                Loan Officer    Male    2
# 148  149                Cash Manager    Male    2
# 66    67                Loan Officer  Female    3
# 82    83                      Banker    Male    3
# 136  137             Business Broker    Male    3
# ..   ...                         ...     ...  ...
# 77    78  Call Center Representative  Female   21
# 20    21                   Treasurer  Female   22
# 59    60         Associate Professor    Male   22
# 75    76            Mobile Developer    Male   22
# 150  151            Mobile Developer  Female   23
#
#                       Email Address FirstName LastName  marks  speed  stength
# 74     Roger_Roscoe7909@joiniaa.com       Roger Roscoe      2      0        0
# 148      Jacob_Smith8526@eirey.tech        Jacob Smith      0      0        2
# 66   Callie_Appleton8542@famism.biz    Callie Appleton      1      2        0
# ...

# %%
print(df.columns)
# Out:
# Index(['ID', 'Job Title', 'Gender', 'new', 'Email Address',
#        'FirstName LastName', 'marks', 'speed', 'stength'],
#       dtype='object')

# %%
l=['ID', 'Job Title', 'Email Address',
       'FirstName LastName', 'marks', 'speed', 'stength', 'Gender', 'new']

# %%
df=df[l]
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  new
# 0          Nathan Farmer      0      4        7    Male   11
# 1      Marigold Woodcock      2      6        0  Female    8
# ...

# %%
df=df.drop(columns=("new"))
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df["new"]=df.iloc[:,4:7].sum(axis=1)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  new
# 0          Nathan Farmer      0      4        7    Male   11
# 1      Marigold Woodcock      2      6        0  Female    8
# ...

# %%
df=df.sort_values("new",ascending=False)
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_10028\1914847251.py:1: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   df=df.sort_values("new",ascending=False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'new'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 df=df.sort_values("new",ascending=False)
#       2 df
#
# File ~\.conda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
df["dg"]=(df["new"]-5)*(5)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.conda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df
# Out:
# 150    90
# 59     85
# 75     85
# 20     85
# 63     80
#        ..
# 136   -10
# 66    -10
# 82    -10
# 148   -15
# 74    -15
# Name: new, Length: 250, dtype: int64

# %% [markdown]
# # ep6 group by

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
d=df.groupby("Gender").count()
d
# Out:
#          ID  Job Title  Email Address  FirstName LastName  marks  speed  \
# Gender
# Female  133        133            133                 133    133    133
# Male    117        117            117                 117    117    117
#
#         stength
# Gender
# Female      133
# Male        117

# %%
g=df.groupby("Gender")["speed"].count()
g
# Out:
# Gender
# Female    133
# Male      117
# Name: speed, dtype: int64

# %%
d=df.groupby("Gender")["marks"].count()
d
# Out:
# Gender
# Female    133
# Male      117
# Name: marks, dtype: int64

# %%
b=df.groupby("Gender")["marks"].sum()
b
# Out:
# Gender
# Female    578
# Male      457
# Name: marks, dtype: int64

# %%
g=df.groupby("Gender")["speed"].mean()
g
# Out:
# Gender
# Female    3.969925
# Male      3.829060
# Name: speed, dtype: float64

# %%
n=df.groupby("Gender").sum()
n
# Out:
#            ID  marks  speed  stength
# Gender
# Female  17133    578    528      560
# Male    14242    457    448      433

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  250 non-null    int64
#  1   Job Title           250 non-null    object
#  2   Email Address       250 non-null    object
#  3   FirstName LastName  250 non-null    object
#  4   marks               250 non-null    int64
#  5   speed               250 non-null    int64
#  6   stength             250 non-null    int64
#  7   Gender              250 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 15.8+ KB
# None

# %%
s=df.describe(include="all")
s
# Out:
#                 ID          Job Title                Email Address  \
# count   250.000000                250                          250
# unique         NaN                 60                          250
# top            NaN  Software Engineer  Nathan_Farmer3609@gmail.com
# freq           NaN                  9                            1
# mean    125.500000                NaN                          NaN
# std      72.312977                NaN                          NaN
# min       1.000000                NaN                          NaN
# 25%      63.250000                NaN                          NaN
# 50%     125.500000                NaN                          NaN
# 75%     187.750000                NaN                          NaN
# max     250.000000                NaN                          NaN
#
#        FirstName LastName       marks       speed     stength  Gender
# count                 250  250.000000  250.000000  250.000000     250
# ...

# %%
d=df.groupby(["Gender","speed"])["speed"].count()
d
# Out:
# Gender  speed
# Female  8        12
# Male    8         8
# Name: speed, dtype: int64

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
d
# Out:
# Gender  speed
# Female  0         8
#         1        15
#         2        26
#         3        15
#         4        14
#         5        13
#         6        11
#         7        19
#         8        12
# Male    0        21
#         1        10
#         2         9
#         3        12
#         4        15
#         5        10
#         6        15
#         7        16
#         8         9
# Name: marks, dtype: int64

# %%
df=df.sort_values("speed",ascending=False).head(25)
df
# Out:
#       ID              Job Title                    Email Address  \
# 101  102                Auditor    Logan_Saunders8829@deons.tech
# 26    27              Inspector       Sasha_Owen4960@irrepsy.com
# 44    45      Food Technologist     Logan_Bayliss8869@mafthy.com
# 152  153          Web Developer        Monica_Noon764@mafthy.com
# 176  177  Healthcare Specialist      Summer_Fowler6971@corti.com
# 154  155               Designer      Roger_Bowen7866@cispeto.com
# 121  122         Budget Analyst      Gabriel_Walsh7061@acrit.org
# 98    99        Project Manager      Gil_Thornton3163@guentu.biz
# 208  209                 Doctor     Cherish_Young5266@supunk.biz
# 225  226                Cashier      Helen_Verdon1253@ovock.tech
# 216  217               Operator      Ethan_Connor2750@kideod.biz
# 17    18              Webmaster        Hank_Miller1691@zorer.org
# 114  115         Retail Trainee     Rocco_Mcneill4859@nimogy.biz
# ...

# %%
df=df.groupby("Gender")["speed"].mean()
df
# Out:
# Gender
# Female    8.0
# Male      8.0
# Name: speed, dtype: float64

# %%
df1=df(["speed"]).sum()
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df1=df(["speed"]).sum()
#       2 df1
#
# NameError: name 'df' is not defined

# %%
ef=df.groupby(["Gender","stength"])["marks"].count()
ef
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 ef=df.groupby(["Gender","stength"])["marks"].count()
#       2 ef
#
# File ~\.conda\lib\site-packages\pandas\core\base.py:250, in SelectionMixin.__getitem__(self, key)
#     248 else:
#     249     if key not in self.obj:
# --> 250         raise KeyError(f"Column not found: {key}")
#     251     subset = self.obj[key]
#     252     ndim = subset.ndim
#
# KeyError: 'Column not found: marks'

# %%
df=df.groupby(["speed","Gender"])["marks"].count()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df=df.groupby(["speed","Gender"])["marks"].count()
#       2 df
#
# File ~\.conda\lib\site-packages\pandas\core\base.py:250, in SelectionMixin.__getitem__(self, key)
#     248 else:
#     249     if key not in self.obj:
# --> 250         raise KeyError(f"Column not found: {key}")
#     251     subset = self.obj[key]
#     252     ndim = subset.ndim
#
# KeyError: 'Column not found: marks'

# %%
df.loc[df["speed"]>5,"stength"]="fast"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed stength  Gender
# 0          Nathan Farmer      0      4    fast    Male
# 1      Marigold Woodcock      2      6    fast  Female
# ...

# %%
df.loc[(df["speed"]>5) & (df["speed"]<10),"stength"]="mediam"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed stength  Gender
# 0          Nathan Farmer      0      4    fast    Male
# 1      Marigold Woodcock      2      6  mediam  Female
# ...

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed stength  Gender
# 0          Nathan Farmer      0      4    fast    Male
# 1      Marigold Woodcock      2      6  mediam  Female
# ...

# %%
df.loc[(df["speed"]>5) & (df["speed"]<10),"marks"]="mediam"
df
f=df.head(20)
f
# Out:
#     ID              Job Title                    Email Address  \
# 0    1           CNC Operator      Nathan_Farmer3609@gmail.com
# 1    2                 Doctor  Marigold_Woodcock8298@liret.org
# 2    3      Food Technologist     Joseph_Verdon3286@deons.tech
# 3    4            Electrician     Emely_Coleman2150@bauros.biz
# 4    5        Business Broker       Ciara_Parker1651@gmail.com
# 5    6       Ambulatory Nurse     Angelina_Owen9607@kideod.biz
# 6    7           CNC Operator         Aiden_Mann5166@deavo.com
# 7    8              Inspector   Hayden_Baldwin3297@womeona.net
# 8    9            Stockbroker     Ethan_Sheldon3123@elnee.tech
# 9   10  Healthcare Specialist        Logan_Pearce715@brety.org
# 10  11                Auditor   William_Vollans4616@nickia.com
# 11  12          Web Developer  Victoria_Bingham8353@supunk.biz
# 12  13        Assistant Buyer        Vivian_King5503@acrit.org
# 13  14  Healthcare Specialist      Skylar_Hogg3190@womeona.net
# ...

# %%
df["New"]=1
df.loc[(df["speed"]>5) & (df["speed"]<10),"New"]="love"
f=df.head(50)
f
# Out:
#     ID                    Job Title                     Email Address  \
# 0    1                 CNC Operator       Nathan_Farmer3609@gmail.com
# 1    2                       Doctor   Marigold_Woodcock8298@liret.org
# 2    3            Food Technologist      Joseph_Verdon3286@deons.tech
# 3    4                  Electrician      Emely_Coleman2150@bauros.biz
# 4    5              Business Broker        Ciara_Parker1651@gmail.com
# 5    6             Ambulatory Nurse      Angelina_Owen9607@kideod.biz
# 6    7                 CNC Operator          Aiden_Mann5166@deavo.com
# 7    8                    Inspector    Hayden_Baldwin3297@womeona.net
# 8    9                  Stockbroker      Ethan_Sheldon3123@elnee.tech
# 9   10        Healthcare Specialist         Logan_Pearce715@brety.org
# 10  11                      Auditor    William_Vollans4616@nickia.com
# 11  12                Web Developer   Victoria_Bingham8353@supunk.biz
# ...

# %%
d=df["Gender"].unique()
d
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
f=df["speed"].unique()
f
# Out:
# array([4, 6, 1, 2, 3, 0, 5, 7, 8], dtype=int64)

# %%
g=df["stength"].unique()
g
# Out:
# array(['fast', 'mediam', 5, 4, 6, 7, 2, 3, 0, 1], dtype=object)

# %%
r=df["marks"].unique()
r
# Out:
# array([0, 'mediam', 1, 5, 6, 2, 8, 4, 7, 3], dtype=object)

# %%
h=df["Job Title"].unique()
list(h)
# Out:
# ['CNC Operator',
#  'Doctor',
#  'Food Technologist',
#  'Electrician',
#  'Business Broker',
#  'Ambulatory Nurse',
#  'Inspector',
#  'Stockbroker',
#  'Healthcare Specialist',
#  'Auditor',
#  'Web Developer',
#  'Assistant Buyer',
#  'Loan Officer',
#  'HR Specialist',
#  'Retail Trainee',
#  'Webmaster',
#  'Cook',
#  'Treasurer',
#  'Accountant',
#  'Executive Director',
#  'Lecturer',
#  'Production Painter',
#  'Associate Professor',
#  'Chef Manager',
#  'Software Engineer',
#  'Insurance Broker',
#  'Cashier',
#  'Front Desk Coordinator',
#  'Global Logistics Supervisor',
#  'Steward',
#  'Clerk',
#  'Budget Analyst',
#  'Bellman',
#  'HR Coordinator',
#  'Machine Operator',
#  'Bookkeeper',
#  'Investment  Advisor',
#  'Pharmacist',
#  'Dentist',
#  'Audiologist',
#  'Design Engineer',
#  'Mobile Developer',
#  'Paramedic',
#  'Biologist',
#  'Call Center Representative',
#  'Health Educator',
#  'Banker',
#  'Operator',
#  'Systems Administrator',
#  'IT Support Staff',
# ...

# %%
df.loc[(df["speed"]>5),"stength"]="xxx"
f=df.head(50)
f
# Out:
#     ID                    Job Title                     Email Address  \
# 0    1                 CNC Operator       Nathan_Farmer3609@gmail.com
# 1    2                       Doctor   Marigold_Woodcock8298@liret.org
# 2    3            Food Technologist      Joseph_Verdon3286@deons.tech
# 3    4                  Electrician      Emely_Coleman2150@bauros.biz
# 4    5              Business Broker        Ciara_Parker1651@gmail.com
# 5    6             Ambulatory Nurse      Angelina_Owen9607@kideod.biz
# 6    7                 CNC Operator          Aiden_Mann5166@deavo.com
# 7    8                    Inspector    Hayden_Baldwin3297@womeona.net
# 8    9                  Stockbroker      Ethan_Sheldon3123@elnee.tech
# 9   10        Healthcare Specialist         Logan_Pearce715@brety.org
# 10  11                      Auditor    William_Vollans4616@nickia.com
# 11  12                Web Developer   Victoria_Bingham8353@supunk.biz
# ...

# %%
df.loc[(df["speed"]>5)& (df["speed"]<10),"Gender"]="girl"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName   marks  speed stength  Gender   New
# 0          Nathan Farmer       0      4    fast    Male     1
# 1      Marigold Woodcock  mediam      6     xxx    girl  love
# ...

# %%
df.loc[(df["Gender"]=="Female"),"speed"]="cc"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName   marks speed stength  Gender   New
# 0          Nathan Farmer       0     4    fast    Male     1
# 1      Marigold Woodcock  mediam     6     xxx    girl  love
# ...

# %%
g=df["speed"].unique()
g
# Out:
# array([4, 6, 1, 'cc', 0, 3, 7, 8, 2, 5], dtype=object)

# %%
g=df.sort_values("marks",ascending=False)
g
# Out:
#       ID           Job Title                       Email Address  \
# 110  111         Stockbroker           Kurt_Ebden5990@typill.biz
# 237  238      Budget Analyst      Cedrick_Weasley3761@sveldo.biz
# 151  152  Production Painter           Hope_Ellery9146@extex.org
# 57    58  Executive Director          Isla_Lindsay6967@yahoo.com
# 170  171      Budget Analyst        Carol_Funnell3000@nickia.com
# ..   ...                 ...                                 ...
# 179  180           Physician       Henry_Hopkinson4304@sheye.org
# 183  184            Operator           Chad_Tanner1625@vetan.org
# 187  188         Stockbroker          Mason_Dann2636@womeona.net
# 209  210         Stockbroker      Freya_Radcliffe2196@deons.tech
# 249  250              Banker  Ember_Richards2215@infotech44.tech
#
#     FirstName LastName  marks  speed  stength  Gender
# 110         Kurt Ebden      8      3        3    Male
# 237    Cedrick Weasley      8      2        4    Male
# ...

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df.loc[(df["Gender"]=="Female"),"speed"]="nnn"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName marks speed stength  Gender
# 0          Nathan Farmer     0     4       7    Male
# 1      Marigold Woodcock     2   nnn       0  Female
# ...

# %%
df.loc[(df["Gender"]=="Male"),"marks"]="sex"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName marks speed stength  Gender
# 0          Nathan Farmer   sex     4       7    Male
# 1      Marigold Woodcock     2   nnn       0  Female
# ...

# %%
df.loc[(df["Gender"]=="Female"),"stength"]="hhh"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName marks speed stength  Gender
# 0          Nathan Farmer   sex     4       7    Male
# 1      Marigold Woodcock     2   nnn     hhh  Female
# ...

# %%
df.loc[(df["speed"]==5),"marks"]="max"
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName marks speed stength  Gender
# 0          Nathan Farmer   sex     4       7    Male
# 1      Marigold Woodcock     2   nnn     hhh  Female
# ...

# %%
df.loc[(df["stength"]>5) & (df["stength"]<10),"Gender"]="xxx"
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df.loc[(df["stength"]>5) & (df["stength"]<10),"Gender"]="xxx"
#       2 df
#
# File ~\.conda\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\.conda\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\.conda\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %% [markdown]
# # user define fuction ep 8

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
def nikhil(v):
    if(v%2==0):
        return "even"
    else:
        return "odd"
df["result"]=df["speed"].apply(nikhil)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender result
# 0          Nathan Farmer      0      4        7    Male   even
# 1      Marigold Woodcock      2      6        0  Female   even
# ...

# %%
def rahul(v):
    return v.upper()
df["result"]=df["Job Title"].apply(rahul)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender             result  \
# 0          Nathan Farmer      0      4        7    Male       CNC OPERATOR
# ...

# %%
def nik(v):
    return v*10
df["love"]=df["speed"].apply(nik)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender             result  \
# 0          Nathan Farmer      0      4        7    Male       CNC OPERATOR
# ...

# %%
def niks(v):
    return v+20*10
df["boobs"]=df["marks"].apply(niks)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender             result  \
# 0          Nathan Farmer      0      4        7    Male       CNC OPERATOR
# ...

# %%
def nikhil(v):
    if(v%2==0):
        return "Even"
    else:
        return "Odd"
df["Data"]=df["stength"].apply(nikhil)
df
h=df.drop(columns="choot")
h
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  Data
# 0          Nathan Farmer      0      4        7    Male   Odd
# 1      Marigold Woodcock      2      6        0  Female  Even
# ...

# %%
a=4
def nik():
    a=5
nik()
print(a)
# Out:
# 4

# %%
a=4
def nik():
    global a
    a=5
nik()
print(a)
# Out:
# 5

# %%
a=0
def nik(v):
    global a
    if(a<150):
        a+=1
        return v.upper()
    else:
        a+=1
        return v
df["new"]=df["Job Title"].apply(nik)
df
df=df.head(151)
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_1400\1259572491.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["new"]=df["Job Title"].apply(nik)
#       ID              Job Title                    Email Address  \
# 0      1           CNC Operator      Nathan_Farmer3609@gmail.com
# 1      2                 Doctor  Marigold_Woodcock8298@liret.org
# 2      3      Food Technologist     Joseph_Verdon3286@deons.tech
# 3      4            Electrician     Emely_Coleman2150@bauros.biz
# 4      5        Business Broker       Ciara_Parker1651@gmail.com
# ..   ...                    ...                              ...
# 146  147  Healthcare Specialist        Morgan_Drew7875@twace.org
# ...

# %%
a=0
def love(v):
    global a
    if(a<100):
        a+=1
        return v.upper()
    else:
        a+=1
        return v
df["res"]=df["FirstName LastName"].apply(love)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender                  res
# 0          Nathan Farmer      0      4        7    Male        NATHAN FARMER
# ...

# %%
df["new"]=df["ID"].astype(str)+":"+df["Job Title"]
def fun(v):
    l=v.split(":")
    if(int(l[0])%2==0):
        return l[1].upper()
    else:
        return l[1] 
    
df["love"]=df["new"].agg(fun)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  \
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df["ID"]=df["ID"].astype(object)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  250 non-null    object
#  1   Job Title           250 non-null    object
#  2   Email Address       250 non-null    object
#  3   FirstName LastName  250 non-null    object
#  4   marks               250 non-null    int64
#  5   speed               250 non-null    int64
#  6   stength             250 non-null    int64
#  7   Gender              250 non-null    object
#  8   new                 250 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 17.7+ KB
# None

# %%
fun=lambda x: x*2+3
df["total"]=df["speed"].apply(fun)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  \
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
xy=lambda x: x*2
df["xxx"]=df["stength"].apply(xy)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender  xxx
# 0          Nathan Farmer      0      4        7    Male   14
# 1      Marigold Woodcock      2      6        0  Female    0
# ...

# %%
df["speed"]=df["speed"].astype(str)
df["girl"]=df["speed"].astype(str)+":"+df["Gender"]
def dc(b):
    l=b.split(":")
    if(int(l[0]%2)==0):
        return l[1].upper()
    else:
        return l[1]
df["boy"]=df["girl"].agg(dc)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\apply.py:1106, in SeriesApply.agg(self)
#    1105 try:
# -> 1106     result = self.obj.apply(f)
#    1107 except (ValueError, AttributeError, TypeError):
#
# File ~\.conda\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\.conda\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\.conda\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
# ...

# %%
c=lambda x: x*4+14
df["bb"]=df["marks"].apply(c)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks speed  stength  Gender       sex      girl  bb
# 0          Nathan Farmer      0     4        7    Male    4:Male    4:Male  14
# ...

# %%
v=lambda x: x*22/7
df["cal"]=df["marks"].apply(v)
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks speed  stength  Gender       sex      girl  \
# 0          Nathan Farmer      0     4        7    Male    4:Male    4:Male
# ...

# %% [markdown]
# # ep9 advance indexing in pandas

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df=df.loc[(df["marks"]==5) | (df["marks"]==8)]
df
# Out:
#       ID              Job Title                     Email Address  \
# 3      4            Electrician      Emely_Coleman2150@bauros.biz
# 8      9            Stockbroker      Ethan_Sheldon3123@elnee.tech
# 9     10  Healthcare Specialist         Logan_Pearce715@brety.org
# 19    20  Healthcare Specialist         Chuck_Flett3499@deavo.com
# 21    22             Accountant      Ronald_Gilmour5790@sheye.org
# ..   ...                    ...                               ...
# 241  242              Treasurer        Logan_Stone2619@nimogy.biz
# 242  243         Retail Trainee  Johnathan_Dempsey1198@nanoff.biz
# 244  245              Treasurer     Stella_Stevens8774@typill.biz
# 246  247      Food Technologist         Erick_Janes4873@yahoo.com
# 248  249                Bellman        Lynn_Heaton6452@nanoff.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 3        Emely Coleman      5      2        7  Female
# 8        Ethan Sheldon      8      0        1    Male
# ...

# %%
l=[5,8]
df=df.loc[df["marks"].isin(l)]
df
# Out:
#       ID              Job Title                     Email Address  \
# 3      4            Electrician      Emely_Coleman2150@bauros.biz
# 8      9            Stockbroker      Ethan_Sheldon3123@elnee.tech
# 9     10  Healthcare Specialist         Logan_Pearce715@brety.org
# 19    20  Healthcare Specialist         Chuck_Flett3499@deavo.com
# 21    22             Accountant      Ronald_Gilmour5790@sheye.org
# ..   ...                    ...                               ...
# 241  242              Treasurer        Logan_Stone2619@nimogy.biz
# 242  243         Retail Trainee  Johnathan_Dempsey1198@nanoff.biz
# 244  245              Treasurer     Stella_Stevens8774@typill.biz
# 246  247      Food Technologist         Erick_Janes4873@yahoo.com
# 248  249                Bellman        Lynn_Heaton6452@nanoff.biz
#
#     FirstName LastName  marks  speed  stength  Gender
# 3        Emely Coleman      5      2        7  Female
# 8        Ethan Sheldon      8      0        1    Male
# ...

# %%
v=[5,7]
df=df.loc[df["speed"].isin(v)]
df
# Out:
#       ID                   Job Title                        Email Address  \
# 36    37                       Clerk         Oliver_Cadman8864@gompie.com
# 40    41                  Accountant         Estrella_James5144@sheye.org
# 57    58          Executive Director           Isla_Lindsay6967@yahoo.com
# 60    61                 Audiologist         Phillip_Brock3215@bauros.biz
# 81    82                     Steward           Liam_Drake8779@dionrab.com
# 86    87       Systems Administrator            Lynn_Thomas8337@qater.org
# 113  114                   Biologist          Liam_Bennett8055@sveldo.biz
# 117  118  Call Center Representative          Jolene_Walsh9255@typill.biz
# 150  151            Mobile Developer        Logan_Appleton2462@nanoff.biz
# 175  176                CNC Operator       Scarlett_Lucas1449@womeona.net
# 182  183         Associate Professor         Johnny_Stewart5078@acrit.org
# 189  190                       Clerk        George_Willis9473@grannar.com
# ...

# %%
k=[5,6]
df=df.loc[df["marks"].isin(k)]
df
# Out:
#       ID                    Job Title                        Email Address  \
# 3      4                  Electrician         Emely_Coleman2150@bauros.biz
# 9     10        Healthcare Specialist            Logan_Pearce715@brety.org
# 19    20        Healthcare Specialist            Chuck_Flett3499@deavo.com
# 21    22                   Accountant         Ronald_Gilmour5790@sheye.org
# 25    26          Associate Professor         Makena_Pearson4350@jiman.org
# 26    27                    Inspector           Sasha_Owen4960@irrepsy.com
# 32    33       Front Desk Coordinator        Sarah_Whatson7304@bulaffy.com
# 33    34  Global Logistics Supervisor             Boris_Reid7305@sheye.org
# 36    37                        Clerk         Oliver_Cadman8864@gompie.com
# 38    39                      Bellman         Julian_Webster976@fuliss.net
# 56    57                         Cook      Julian_Villiger5174@joiniaa.com
# ...

# %%
df=df.reset_index(drop=False)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df=df.reset_index(drop=False)
#       2 df
#
# File ~\.conda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\.conda\lib\site-packages\pandas\core\frame.py:5839, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5833         if lab is not None:
#    5834             # if we have the codes, extract the values with a mask
#    5835             level_values = algorithms.take(
# ...

# %%
df
# Out:
#       ID          Job Title                       Email Address  \
# 0      1       CNC Operator         Nathan_Farmer3609@gmail.com
# 1      2             Doctor     Marigold_Woodcock8298@liret.org
# 2      3  Food Technologist        Joseph_Verdon3286@deons.tech
# 3      4        Electrician        Emely_Coleman2150@bauros.biz
# 4      5    Business Broker          Ciara_Parker1651@gmail.com
# ..   ...                ...                                 ...
# 245  246            Cashier           Stacy_Rossi7460@twace.org
# 246  247  Food Technologist           Erick_Janes4873@yahoo.com
# 247  248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 248  249            Bellman          Lynn_Heaton6452@nanoff.biz
# 249  250             Banker  Ember_Richards2215@infotech44.tech
#
#       FirstName LastName  marks  speed  stength  Gender
# 0          Nathan Farmer      0      4        7    Male
# 1      Marigold Woodcock      2      6        0  Female
# ...

# %%
df=df.set_index(["speed","marks"])
df
# Out:
#               ID          Job Title                       Email Address  \
# speed marks
# 4     0        1       CNC Operator         Nathan_Farmer3609@gmail.com
# 6     2        2             Doctor     Marigold_Woodcock8298@liret.org
# 1     1        3  Food Technologist        Joseph_Verdon3286@deons.tech
# 2     5        4        Electrician        Emely_Coleman2150@bauros.biz
#       6        5    Business Broker          Ciara_Parker1651@gmail.com
# ...          ...                ...                                 ...
#       1      246            Cashier           Stacy_Rossi7460@twace.org
# 8     5      247  Food Technologist           Erick_Janes4873@yahoo.com
# 0     2      248      Web Developer  Sebastian_Alexander4528@sveldo.biz
# 5     8      249            Bellman          Lynn_Heaton6452@nanoff.biz
#       0      250             Banker  Ember_Richards2215@infotech44.tech
#
#               FirstName LastName  stength  Gender
# speed marks
# ...

# %%
df=df.sort_index()
df1=df.loc[1:6]
df1
# Out:
#               ID              Job Title                     Email Address  \
# speed marks
# 1     1        3      Food Technologist      Joseph_Verdon3286@deons.tech
#       1       24               Lecturer        Abdul_Watson2655@deavo.com
#       1       29      Software Engineer  Charlize_Utterson3661@famism.biz
#       1       72  Healthcare Specialist        Gina_Seymour8804@deavo.com
#       1       86                  Clerk        Liam_Sawyer3368@sveldo.biz
# ...          ...                    ...                               ...
# 6     7      204     Executive Director      Carla_Reynolds5056@brety.org
#       8       56      Software Engineer  Alexander_Egerton9770@twipet.com
#       8       60    Associate Professor       Doug_Chapman6173@gembat.biz
#       8       76       Mobile Developer     Gil_Blackwall1627@irrepsy.com
#       8      231    Staffing Consultant      Aisha_Mullins5879@iatim.tech
#
#             FirstName LastName  stength  Gender
# speed marks
# ...

# %%
df1.to_csv("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df1.to_csv("")
#
# NameError: name 'df1' is not defined

# %% [markdown]
# # ep10

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA (3).csv")
df
# Out:
#                    name                car        Date             country  \
# 0        Marshal Moxley                 ES   6/24/2022               China
# 1         Talbert Haack              Evora   1/25/2022       United States
# 2          Stanly Gogin           6 Series   4/15/2022               China
# 3        Trenna Sindell       Grand Vitara   9/21/2022           Indonesia
# 4           Hana Netley           L-Series   2/22/2022               China
# 5          Lishe Mather               Echo  06-10-2022              Canada
# 6      Malcolm Holworth          D350 Club   8/20/2022         Philippines
# 7       Frank McGuiness             Camaro  09-02-2022              France
# 8     Angelita Kilcoyne     Econoline E350   3/29/2022           Indonesia
# 9   Eachelle Vasilechko           LaCrosse  10/20/2022              Brazil
# 10          Denni Dyers      Yukon XL 2500  05-09-2022                Peru
# ...

# %%
d=df["saving"].replace("$","")
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 d=df["saving"].replace("$","")
#       2 d
#
# File ~\.conda\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\.conda\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1000 non-null   object
#  1   car            1000 non-null   object
#  2   Date           1000 non-null   object
#  3   country        1000 non-null   object
#  4   email address  1000 non-null   object
#  5   saving         1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB
# None

# %%
import numpy as np
df1=df["saving"].replace("$"," ")
df1
# Out:
# 0      $7.69
# 1      $7.97
# 2      $3.65
# 3      $0.94
# 4      $8.65
#        ...
# 995    $2.77
# 996    $9.88
# 997    $3.72
# 998    $4.68
# 999    $6.23
# Name: saving, Length: 1000, dtype: object

# %%
def np(b):
    if(isnumeric==True):
        return b
    else:
        return 
    
df["new"]=df["saving"].apply(np)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 7>()
#       4     else:
#       5         return
# ----> 7 df["new"]=df["saving"].apply(np)
#       8 df
#
# File ~\.conda\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\.conda\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# ...

# %%
df
# Out:
#                    name                car        Date             country  \
# 0        Marshal Moxley                 ES   6/24/2022               China
# 1         Talbert Haack              Evora   1/25/2022       United States
# 2          Stanly Gogin           6 Series   4/15/2022               China
# 3        Trenna Sindell       Grand Vitara   9/21/2022           Indonesia
# 4           Hana Netley           L-Series   2/22/2022               China
# 5          Lishe Mather               Echo  06-10-2022              Canada
# 6      Malcolm Holworth          D350 Club   8/20/2022         Philippines
# 7       Frank McGuiness             Camaro  09-02-2022              France
# 8     Angelita Kilcoyne     Econoline E350   3/29/2022           Indonesia
# 9   Eachelle Vasilechko           LaCrosse  10/20/2022              Brazil
# 10          Denni Dyers      Yukon XL 2500  05-09-2022                Peru
# ...

# %%
df["saving"]=df["saving"].str.replace("$"," ")
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_25420\663269432.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["saving"]=df["saving"].str.replace("$"," ")
#                    name                car        Date             country  \
# 0        Marshal Moxley                 ES   6/24/2022               China
# 1         Talbert Haack              Evora   1/25/2022       United States
# 2          Stanly Gogin           6 Series   4/15/2022               China
# 3        Trenna Sindell       Grand Vitara   9/21/2022           Indonesia
# 4           Hana Netley           L-Series   2/22/2022               China
# 5          Lishe Mather               Echo  06-10-2022              Canada
# 6      Malcolm Holworth          D350 Club   8/20/2022         Philippines
# ...

# %%
a=df["saving"].mean()
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: ' 7.69 7.97 3.65 0.94 8.65 4.36 3.62 7.28 3.91 4.22 7.69 2.77 5.94 9.09 2.13 1.90 8.86 3.23 6.47 0.77 0.14 3.97 7.20 8.38 0.43 4.27 6.48 2.03 2.99 4.80 4.66 4.74 0.43'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\nanops.py:1626, in _ensure_numeric(x)
#    1625 try:
# -> 1626     x = complex(x)
#    1627 except ValueError as err:
#    1628     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# ...

# %%
import numpy as np
df["saving"]=df["saving"].astypenpint)
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 df["saving"]=df["saving"].astype(int)
#       3 print(df.info())
#
# File ~\.conda\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\.conda\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           33 non-null     object
#  1   car            33 non-null     object
#  2   Date           33 non-null     object
#  3   country        33 non-null     object
#  4   email address  33 non-null     object
#  5   saving         33 non-null     object
#  6   Day            33 non-null     int64
#  7   Month          33 non-null     int64
#  8   Year           33 non-null     int64
# dtypes: int64(3), object(6)
# memory usage: 2.4+ KB
# None

# %%
a=df["Day"].mean()
a
# Out:
# 14.545454545454545

# %%
df1=df.loc[df["Day"]==a]
df1
# Out:
# Empty DataFrame
# Columns: [name, car, Date, country, email address, saving, Day, Month, Year]
# Index: []

# %%
f=df["Date"].max()
f
# Out:
# nan

# %% [markdown]
# # ep11

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Desktop\Walmart.csv")
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
ef=df.groupby("Store")["Weekly_Sales"].mean()
ef
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %%
f=df.info()
f
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
b=df.describe(include="all")
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 b=df.describe(include="all")
#       2 b
#
# NameError: name 'df' is not defined

# %%
fg=df.groupby("Store")["Weekly_Sales"].max()
fg
# Out:
# Store
# 1     2387950.20
# 2     3436007.68
# 3      605990.41
# 4     3676388.98
# 5      507900.07
# 6     2727575.18
# 7     1059715.27
# 8     1511641.09
# 9      905324.68
# 10    3749057.69
# 11    2306265.36
# 12    1768249.89
# 13    3595903.20
# 14    3818686.45
# 15    1368318.17
# 16    1004730.69
# 17    1309226.79
# 18    2027507.15
# 19    2678206.42
# 20    3766687.43
# 21    1587257.78
# 22    1962445.04
# 23    2734277.10
# 24    2386015.75
# 25    1295391.19
# 26    1573982.47
# 27    3078162.08
# 28    2026026.39
# 29    1130926.79
# 30     519354.88
# 31    2068942.97
# 32    1959526.96
# 33     331173.51
# 34    1620748.25
# 35    1781866.98
# 36     489372.02
# 37     605791.46
# 38     499267.66
# 39    2554482.84
# 40    1648829.18
# 41    2263722.68
# 42     674919.45
# 43     725043.04
# 44     376233.89
# 45    1682862.03
# Name: Weekly_Sales, dtype: float64

# %%
import numpy as np
pdf=df.pivot_table(index="Store", values="Weekly_Sales",aggfunc=[np.max])
pdf
# Out:
#               amax
#       Weekly_Sales
# Store
# 1       2387950.20
# 2       3436007.68
# 3        605990.41
# 4       3676388.98
# 5        507900.07
# 6       2727575.18
# 7       1059715.27
# 8       1511641.09
# 9        905324.68
# 10      3749057.69
# 11      2306265.36
# 12      1768249.89
# 13      3595903.20
# 14      3818686.45
# 15      1368318.17
# 16      1004730.69
# 17      1309226.79
# 18      2027507.15
# 19      2678206.42
# 20      3766687.43
# 21      1587257.78
# 22      1962445.04
# 23      2734277.10
# 24      2386015.75
# 25      1295391.19
# 26      1573982.47
# 27      3078162.08
# 28      2026026.39
# 29      1130926.79
# 30       519354.88
# 31      2068942.97
# 32      1959526.96
# 33       331173.51
# 34      1620748.25
# 35      1781866.98
# 36       489372.02
# 37       605791.46
# 38       499267.66
# 39      2554482.84
# 40      1648829.18
# 41      2263722.68
# 42       674919.45
# 43       725043.04
# 44       376233.89
# 45      1682862.03

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
import pandas as pd
import numpy as np

df1=df.groupby(["Store","Holiday_Flag"])["Weekly_Sales","Temperature"].agg([np.max,np.mean])
df1
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_25504\1420177190.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=df.groupby(["Store","Holiday_Flag"])["Weekly_Sales","Temperature"].agg([np.max,np.mean])
#                    Weekly_Sales               Temperature
#                            amax          mean        amax       mean
# Store Holiday_Flag
# 1     0              2387950.20  1.546957e+06       91.65  69.087669
#       1              2033320.66  1.665748e+06       83.96  57.921000
# 2     0              3436007.68  1.914209e+06       93.34  69.025263
#       1              2658725.29  2.079267e+06       87.65  57.458000
# 3     0               605990.41  4.000648e+05       89.12  72.076617
# ...                         ...           ...         ...        ...
# 43    1               722120.04  6.359463e+05       84.99  58.168000
# ...

# %%
import pandas as pd
import numpy as np
pdf=df.pivot_table(index="Store", values="Weekly_Sales",aggfunc=[np.max])
pdf
# Out:
#               amax
#       Weekly_Sales
# Store
# 1       2387950.20
# 2       3436007.68
# 3        605990.41
# 4       3676388.98
# 5        507900.07
# 6       2727575.18
# 7       1059715.27
# 8       1511641.09
# 9        905324.68
# 10      3749057.69
# 11      2306265.36
# 12      1768249.89
# 13      3595903.20
# 14      3818686.45
# 15      1368318.17
# 16      1004730.69
# 17      1309226.79
# 18      2027507.15
# 19      2678206.42
# 20      3766687.43
# 21      1587257.78
# 22      1962445.04
# 23      2734277.10
# 24      2386015.75
# 25      1295391.19
# 26      1573982.47
# 27      3078162.08
# 28      2026026.39
# 29      1130926.79
# 30       519354.88
# 31      2068942.97
# 32      1959526.96
# 33       331173.51
# 34      1620748.25
# 35      1781866.98
# 36       489372.02
# 37       605791.46
# 38       499267.66
# 39      2554482.84
# 40      1648829.18
# 41      2263722.68
# 42       674919.45
# 43       725043.04
# 44       376233.89
# 45      1682862.03

# %%
import pandas as pd
import numpy as np
pdf=df.pivot_table(index="Store", columns="Holiday_Flag",values="Weekly_Sales",aggfunc=[np.max])
pdf
# Out:
#                     amax
# Holiday_Flag           0           1
# Store
# 1             2387950.20  2033320.66
# 2             3436007.68  2658725.29
# 3              605990.41   565567.84
# 4             3676388.98  3004702.33
# 5              466010.25   507900.07
# 6             2727575.18  2267452.40
# 7             1059715.27   949075.87
# 8             1511641.09  1261693.16
# 9              905324.68   814753.50
# 10            3749057.69  2950198.64
# 11            2306265.36  1848953.48
# 12            1768249.89  1601377.41
# 13            3595903.20  2864170.61
# 14            3818686.45  2921709.71
# 15            1368318.17  1120018.92
# 16            1004730.69   712422.40
# 17            1309226.79  1255633.29
# 18            2027507.15  1653759.36
# 19            2678206.42  1993367.83
# 20            3766687.43  2906233.25
# 21            1587257.78  1245628.61
# 22            1962445.04  1564502.26
# 23            2734277.10  2072685.05
# ...

# %%
import pandas as pd
import numpy as np
pdf=df.pivot_table(index="Store", columns="Holiday_Flag",values="Weekly_Sales",margins=True)
pdf
# Out:
# Holiday_Flag             0             1           All
# Store
# 1             1.546957e+06  1.665748e+06  1.555264e+06
# 2             1.914209e+06  2.079267e+06  1.925751e+06
# 3             4.000648e+05  4.378110e+05  4.027044e+05
# 4             2.083556e+06  2.243103e+06  2.094713e+06
# 5             3.148923e+05  3.595016e+05  3.180118e+05
# 6             1.555993e+06  1.680908e+06  1.564728e+06
# 7             5.629645e+05  6.724003e+05  5.706173e+05
# 8             9.037434e+05  9.753309e+05  9.087495e+05
# 9             5.405993e+05  5.889508e+05  5.439806e+05
# 10            1.883309e+06  2.113756e+06  1.899425e+06
# 11            1.349465e+06  1.448394e+06  1.356383e+06
# 12            9.992919e+05  1.138140e+06  1.009002e+06
# 13            1.995393e+06  2.113044e+06  2.003620e+06
# 14            2.013489e+06  2.120583e+06  2.020978e+06
# 15            6.170648e+05  7.064060e+05  6.233125e+05
# 16            5.156774e+05  5.667336e+05  5.192477e+05
# ...

# %% [markdown]
# # missing value1 ep 12

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\nikhil pal\Desktop\missing data2.csv")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 12   NaN                     NaN                               NaN
# ...

# %%
import numpy as np
df=df.replace("-",np.NaN)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 12   NaN                     NaN                               NaN
# ...

# %%
print(df.isnull().sum())
# Out:
# ID                     4
# Job Title              7
# Email Address          8
# FirstName LastName     6
# marks                 11
# dtype: int64

# %%
print(df.notnull().sum())
# Out:
# ID                    16
# Job Title             13
# Email Address         12
# FirstName LastName    14
# marks                  9
# dtype: int64

# %%
df
# Out:
#       ID          Job Title                    Email Address  \
# 1   27.0          Inspector       Sasha_Owen4960@irrepsy.com
# 5   31.0            Cashier  Estrella_Vollans9199@nickia.com
# 10  36.0            Steward       Margot_Wren5557@fuliss.net
# 19  45.0  Food Technologist     Logan_Bayliss8869@mafthy.com
#
#    FirstName LastName  marks
# 1          Sasha Owen    5.0
# 5    Estrella Vollans    7.0
# 10        Margot Wren    8.0
# 19      Logan Bayliss    3.0

# %%
df=df.dropna(how="all")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 13   NaN                 Bellman                                 -
# ...

# %%
df=df.dropna(how="any")
df
# Out:
#       ID          Job Title                    Email Address  \
# 1   27.0          Inspector       Sasha_Owen4960@irrepsy.com
# 5   31.0            Cashier  Estrella_Vollans9199@nickia.com
# 10  36.0            Steward       Margot_Wren5557@fuliss.net
# 19  45.0  Food Technologist     Logan_Bayliss8869@mafthy.com
#
#    FirstName LastName  marks
# 1          Sasha Owen    5.0
# 5    Estrella Vollans    7.0
# 10        Margot Wren    8.0
# 19      Logan Bayliss    3.0

# %%
df=df.dropna(thresh=1)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# ...

# %%
df=df.dropna(thresh=3)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# 14  40.0            Chef Manager                               NaN
# 15  41.0              Accountant                               NaN
# ...

# %%
df=df.dropna(how="all",subset=["Job Title","marks"])
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 7   33.0  Front Desk Coordinator                            #NAME?
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# 14  40.0            Chef Manager                               NaN
# 15  41.0              Accountant                               NaN
# 16  42.0                  Doctor          Alba_Hall2107@famism.biz
# ...

# %%
df=df.dropna(how="any",subset=["Job Title","marks"])
df
# Out:
#       ID               Job Title                    Email Address  \
# 1   27.0               Inspector       Sasha_Owen4960@irrepsy.com
# 5   31.0                 Cashier  Estrella_Vollans9199@nickia.com
# 9   35.0  Front Desk Coordinator                              NaN
# 10  36.0                 Steward       Margot_Wren5557@fuliss.net
# 13   NaN                 Bellman                              NaN
# 14  40.0            Chef Manager                              NaN
# 19  45.0       Food Technologist     Logan_Bayliss8869@mafthy.com
#
#    FirstName LastName  marks
# 1          Sasha Owen    5.0
# 5    Estrella Vollans    7.0
# 9        Hank Gosling    0.0
# 10        Margot Wren    8.0
# 13     Julian Webster    5.0
# 14       Kendra Glynn    6.0
# 19      Logan Bayliss    3.0

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 12   NaN                     NaN                               NaN
# ...

# %%
import pandas as pd
import numpy as np

df=df.replace("-",np.NaN)
df
# Out:
#       ID          Job Title                    Email Address  \
# 1   27.0          Inspector       Sasha_Owen4960@irrepsy.com
# 5   31.0            Cashier  Estrella_Vollans9199@nickia.com
# 10  36.0            Steward       Margot_Wren5557@fuliss.net
# 19  45.0  Food Technologist     Logan_Bayliss8869@mafthy.com
#
#    FirstName LastName  marks
# 1          Sasha Owen    5.0
# 5    Estrella Vollans    7.0
# 10        Margot Wren    8.0
# 19      Logan Bayliss    3.0

# %%
print(df.isnull())
# Out:
#        ID  Job Title  Email Address  FirstName LastName  marks
# 0   False       True          False                True  False
# 1   False      False          False               False  False
# 2   False      False           True                True   True
# 3   False       True          False               False  False
# 4   False      False          False               False   True
# 5   False      False          False               False  False
# 6   False       True          False               False   True
# 7   False      False          False                True   True
# 8    True       True          False               False   True
# 9   False      False           True               False  False
# 10  False      False          False               False  False
# 11  False      False           True               False   True
# 12   True       True           True                True   True
# 13   True      False           True               False  False
# ...

# %%
print(df.isnull().sum())
# Out:
# ID                     4
# Job Title              7
# Email Address          8
# FirstName LastName     6
# marks                 11
# dtype: int64

# %%
print(df.notnull())
# Out:
#        ID  Job Title  Email Address  FirstName LastName  marks
# 0    True      False           True               False   True
# 1    True       True           True                True   True
# 2    True       True          False               False  False
# 3    True      False           True                True   True
# 4    True       True           True                True  False
# 5    True       True           True                True   True
# 6    True      False           True                True  False
# 7    True       True           True               False  False
# 8   False      False           True                True  False
# 9    True       True          False                True   True
# 10   True       True           True                True   True
# 11   True       True          False                True  False
# 12  False      False          False               False  False
# 13  False       True          False                True   True
# ...

# %%
print(df.notnull().sum())
# Out:
# ID                    16
# Job Title             13
# Email Address         12
# FirstName LastName    14
# marks                  9
# dtype: int64

# %%
df=df.dropna(how="all")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# ...

# %%
df=df.dropna(thresh=1,how="all")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 13   NaN                 Bellman                                 -
# ...

# %%
df1=df.dropna(thresh=2,how="all")
df1
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# ...

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# ...

# %%
df1=df.dropna(thresh=3,how="any")
df1
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# 14  40.0            Chef Manager                               NaN
# 15  41.0              Accountant                               NaN
# ...

# %%
dfg=df.dropna(thresh=2,subset=["Job Title","marks"])
dfg
# Out:
#       ID               Job Title                    Email Address  \
# 1   27.0               Inspector       Sasha_Owen4960@irrepsy.com
# 5   31.0                 Cashier  Estrella_Vollans9199@nickia.com
# 9   35.0  Front Desk Coordinator                              NaN
# 10  36.0                 Steward       Margot_Wren5557@fuliss.net
# 13   NaN                 Bellman                              NaN
# 14  40.0            Chef Manager                              NaN
# 19  45.0       Food Technologist     Logan_Bayliss8869@mafthy.com
#
#    FirstName LastName  marks
# 1          Sasha Owen    5.0
# 5    Estrella Vollans    7.0
# 9        Hank Gosling    0.0
# 10        Margot Wren    8.0
# 13     Julian Webster    5.0
# 14       Kendra Glynn    6.0
# 19      Logan Bayliss    3.0

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13   NaN                 Bellman                               NaN
# ...

# %% [markdown]
# # ep13 missing data 2

# %%
import pandas as pd
d={'Job Title' : 'user',"marks": "number"}
df=df.fillna(d)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                       d      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 d
# 3   29.0                       d  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                       d      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8      d                       d          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                                 d
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 d
# 13     d                 Bellman                                 d
# ...

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 13   NaN                 Bellman                                 -
# ...

# %%
import pandas as pd
import numpy as np
df=df.replace("-",np.NaN)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 12   NaN                     NaN                               NaN
# ...

# %%
df["ID"]=df["ID"].interpolate()

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8   34.0                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 13  38.5                 Bellman                               NaN
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 12   NaN                     NaN                               NaN
# ...

# %%
df=df.fillna(method="ffill")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager        Sasha_Owen4960@irrepsy.com
# 3   29.0            Chef Manager  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                 Cashier      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8   33.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk        Margot_Wren5557@fuliss.net
# 12  37.0                   Clerk        Margot_Wren5557@fuliss.net
# ...

# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\nikhil pal\Desktop\missing data2.csv")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 12   NaN                     NaN                               NaN
# ...

# %%
import numpy as np
df=df.replace("-",np.NaN)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 12   NaN                     NaN                               NaN
# ...

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                               NaN
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 12   NaN                     NaN                               NaN
# ...

# %%
df=df.fillna(method="bfill")
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0               Inspector      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager  Charlize_Utterson3661@famism.biz
# 3   29.0        Insurance Broker  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0  Front Desk Coordinator      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8   35.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator        Margot_Wren5557@fuliss.net
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk          Alba_Hall2107@famism.biz
# 12  40.0                 Bellman          Alba_Hall2107@famism.biz
# ...

# %%
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                                 -
# 3   29.0                     NaN  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                     NaN      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator                               NaN
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                                 -
# 12   NaN                     NaN                               NaN
# ...

# %%
df1=df.fillna(method="bfill",limit=1)
df1
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0               Inspector      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager  Charlize_Utterson3661@famism.biz
# 3   29.0        Insurance Broker  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0  Front Desk Coordinator      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8   35.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator        Margot_Wren5557@fuliss.net
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                               NaN
# 12   NaN                 Bellman                               NaN
# ...

# %%
df=df.fillna(method="ffill",limit=1,axis=1)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                    26.0      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                      Chef Manager
# 3   29.0                    29.0  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                    32.0      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8    NaN                     NaN          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator            Front Desk Coordinator
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                             Clerk
# 12   NaN                     NaN                               NaN
# ...

# %%
df=df.fillna(method="ffill",limit=1,axis=0)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                    26.0      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager                      Chef Manager
# 3   29.0                    29.0  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                    32.0      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8   33.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator            Front Desk Coordinator
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk                             Clerk
# 12  37.0                   Clerk                             Clerk
# ...

# %%
df=df.fillna(method="ffill",limit=1,axis=0)
df
# Out:
#       ID               Job Title                     Email Address  \
# 0   26.0                     NaN      Makena_Pearson4350@jiman.org
# 1   27.0               Inspector        Sasha_Owen4960@irrepsy.com
# 2   28.0            Chef Manager        Sasha_Owen4960@irrepsy.com
# 3   29.0            Chef Manager  Charlize_Utterson3661@famism.biz
# 4   30.0        Insurance Broker     Belinda_Poulton3802@twace.org
# 5   31.0                 Cashier   Estrella_Vollans9199@nickia.com
# 6   32.0                 Cashier      Selena_Newton6672@eirey.tech
# 7   33.0  Front Desk Coordinator                            #NAME?
# 8   33.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 9   35.0  Front Desk Coordinator          Boris_Reid7305@sheye.org
# 10  36.0                 Steward        Margot_Wren5557@fuliss.net
# 11  37.0                   Clerk        Margot_Wren5557@fuliss.net
# 12  37.0                   Clerk                               NaN
# ...

# %% [markdown]
# # ep14 date column

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA (5).csv")
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#           date1       date2
# ...

# %%
import pandas as pd
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#           date1       date2
# ...

# %%
df["date1"]=df["date1"].str.replace('/','-')
df["date2"]=df["date2"].str.replace('.','-')
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_20688\3395413836.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["date2"]=df["date2"].str.replace('.','-')
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   date1       1000 non-null   object
#  6   date2       1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB
# None

# %%
df["date1"]=pd.to_datetime(df["date1"],format='%d-%m-%Y')
df["date2"]=pd.to_datetime(df["date2"],format='%d-%m-%Y')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\tools\datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~\.conda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 df["date1"]=pd.to_datetime(df["date1"],format='%d-%m-%Y')
#       2 df["date2"]=pd.to_datetime(df["date2"],format='%d-%m-%Y')
#       3 df
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   date1       1000 non-null   object
#  6   date2       1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   date1       1000 non-null   datetime64[ns]
#  6   date2       1000 non-null   datetime64[ns]
#  7   new         1000 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4), timedelta64[ns](1)
# memory usage: 62.6+ KB
# None

# %%
import numpy as np
df["new2"]=df["new"]/np.timedelta64(1,"M")
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df1=df.loc[df['date1']>'2022-3']
df1
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df2=df.loc[df['date2']>='2022-02']
df2
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df3=df.loc[df['date2']>'2022']
df3
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df4=df.loc[df['date2']>='2022-04-01']
df4
# Out:
#        id first_name   last_name                      email       gender  \
# 0       1   Lauraine     Andreia         landreia0@narod.ru       Female
# 1       2     Gannie   MacGuigan  gmacguigan1@bloglines.com         Male
# 2       3      Pippa       Boote        pboote2@comsenz.com       Female
# 3       4      Leela      Emmett         lemmett3@imgur.com       Female
# 4       5   Yovonnda       Spear            yspear4@who.int       Female
# ..    ...        ...         ...                        ...          ...
# 989   990   Tarrance  Sprackling  tspracklingrh@addthis.com  Genderqueer
# 990   991  Milissent   Arkwright  markwrightri@multiply.com      Agender
# 996   997  Ezmeralda      Radmer         eradmerro@tamu.edu       Female
# 997   998   Bethanne       Longo        blongorp@netlog.com   Polygender
# 999  1000     Thorin     Keitley      tkeitleyrr@oakley.com         Male
#
#          date1      date2
# 0   2022-10-18 2022-12-04
# 1   2022-05-27 2022-06-15
# ...

# %%
df5=df.loc[df["date1"]>'2022']
df5
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df6=df.loc[df['date1']>='2022-10-18']
df6
# Out:
#       id first_name  last_name                       email   gender  \
# 0      1   Lauraine    Andreia          landreia0@narod.ru   Female
# 11    12       Mark     Noakes          mnoakesb@prlog.org     Male
# 12    13     Rodney      Rubee             rrubeec@nih.gov     Male
# 17    18    Gustave    Hallums     ghallumsh@sitemeter.com     Male
# 18    19      Nolie    Gemelli       ngemellii@twitter.com   Female
# ..   ...        ...        ...                         ...      ...
# 980  981       Dame     Medway     dmedwayr8@cafepress.com  Agender
# 981  982        Ali     Fardon  afardonr9@sciencedaily.com     Male
# 991  992     Whitby     O'Lynn     wolynnrj@eventbrite.com     Male
# 993  994     Corrie  Stebbings     cstebbingsrl@nsw.gov.au   Female
# 994  995     Gianni    Uzielli       guziellirm@meetup.com     Male
#
#          date1      date2
# 0   2022-10-18 2022-12-04
# 11  2022-12-12 2022-06-10
# 12  2022-11-25 2022-11-17
# 17  2022-12-27 2022-01-29
# ...

# %%
df7=df.loc[(df['date1']>'2022-3') & (df['date2']<'2022-03')]
df7
# Out:
#       id first_name    last_name                         email       gender  \
# 17    18    Gustave      Hallums       ghallumsh@sitemeter.com         Male
# 30    31     Freddy     Handover       fhandoveru@omniture.com         Male
# 32    33  Annemarie     Radborne     aradbornew@eventbrite.com       Female
# 36    37       Viva        Riatt            vriatt10@wiley.com       Female
# 39    40       Izak      Dudenie              idudenie13@51.la         Male
# ..   ...        ...          ...                           ...          ...
# 971  972    Sanders      Domokos  sdomokosqz@ezinearticles.com         Male
# 972  973    Bentley       Simoni         bsimonir0@comsenz.com         Male
# 993  994     Corrie    Stebbings       cstebbingsrl@nsw.gov.au       Female
# 994  995     Gianni      Uzielli         guziellirm@meetup.com         Male
# 998  999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
#
#          date1      date2
# 17  2022-12-27 2022-01-29
# ...

# %%
df8=df.loc[(df['gender']=='Male') & (df["date1"]>='2022-05') & (df["date2"]<'2022-06-21')]
df8
# Out:
#       id first_name   last_name                         email gender  \
# 1      2     Gannie   MacGuigan     gmacguigan1@bloglines.com   Male
# 11    12       Mark      Noakes            mnoakesb@prlog.org   Male
# 17    18    Gustave     Hallums       ghallumsh@sitemeter.com   Male
# 26    27     Skyler  Fernehough         sfernehoughq@sohu.com   Male
# 30    31     Freddy    Handover       fhandoveru@omniture.com   Male
# ..   ...        ...         ...                           ...    ...
# 971  972    Sanders     Domokos  sdomokosqz@ezinearticles.com   Male
# 972  973    Bentley      Simoni         bsimonir0@comsenz.com   Male
# 991  992     Whitby      O'Lynn       wolynnrj@eventbrite.com   Male
# 994  995     Gianni     Uzielli         guziellirm@meetup.com   Male
# 995  996       Ives     Stroban    istrobanrn@livejournal.com   Male
#
#          date1      date2
# 1   2022-05-27 2022-06-15
# 11  2022-12-12 2022-06-10
# 17  2022-12-27 2022-01-29
# 26  2022-10-05 2022-04-28
# ...

# %%
df9=df.loc[df["date1"]>='2022-04']
df9
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# 5       6    Krissie     Whittles          kwhittles5@sogou.com       Female
# ..    ...        ...          ...                           ...          ...
# 994   995     Gianni      Uzielli         guziellirm@meetup.com         Male
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
 df11=df.loc[(df["date1"]>='2022-04') & (df['date2']<='2022-12-04')]
df11
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# 5       6    Krissie     Whittles          kwhittles5@sogou.com       Female
# ..    ...        ...          ...                           ...          ...
# 994   995     Gianni      Uzielli         guziellirm@meetup.com         Male
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df=df.set_index("date2")
df
# Out:
#               id first_name    last_name                         email  \
# date2
# 2022-12-04     1   Lauraine      Andreia            landreia0@narod.ru
# 2022-06-15     2     Gannie    MacGuigan     gmacguigan1@bloglines.com
# 2022-09-04     3      Pippa        Boote           pboote2@comsenz.com
# 2022-11-04     4      Leela       Emmett            lemmett3@imgur.com
# 2022-09-28     5   Yovonnda        Spear               yspear4@who.int
# ...          ...        ...          ...                           ...
# 2022-03-26   996       Ives      Stroban    istrobanrn@livejournal.com
# 2022-04-26   997  Ezmeralda       Radmer            eradmerro@tamu.edu
# 2022-06-03   998   Bethanne        Longo           blongorp@netlog.com
# 2022-02-13   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net
# 2022-11-12  1000     Thorin      Keitley         tkeitleyrr@oakley.com
#
#                  gender      date1
# date2
# 2022-12-04       Female 2022-10-18
# ...

# %%
df=df.loc["2021": "2022"]
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_20688\3266689327.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df=df.loc["2021": "2022"]
#               id first_name    last_name                         email  \
# date2
# 2022-12-04     1   Lauraine      Andreia            landreia0@narod.ru
# 2022-06-15     2     Gannie    MacGuigan     gmacguigan1@bloglines.com
# 2022-09-04     3      Pippa        Boote           pboote2@comsenz.com
# 2022-11-04     4      Leela       Emmett            lemmett3@imgur.com
# 2022-09-28     5   Yovonnda        Spear               yspear4@who.int
# ...          ...        ...          ...                           ...
# 2022-03-26   996       Ives      Stroban    istrobanrn@livejournal.com
# 2022-04-26   997  Ezmeralda       Radmer            eradmerro@tamu.edu
# ...

# %%
df=df.loc['2020-09':"2021-06"]
df
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, date1]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, date1]
# Index: []

# %%
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#           date1       date2
# ...

# %%
df["date1"]=pd.to_datetime(df["date1"],format='%d-%m-%Y')
df["date2"]=pd.to_datetime(df["date2"],format='%d-%m-%Y')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\lib\site-packages\pandas\core\tools\datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File ~\.conda\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 df["date1"]=pd.to_datetime(df["date1"],format='%d-%m-%Y')
#       2 df["date2"]=pd.to_datetime(df["date2"],format='%d-%m-%Y')
#       3 df
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   date1       1000 non-null   object
#  6   date2       1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB
# None

# %%
df["date1"]=pd.to_datetime(df["date1"],format='%d-%m-%Y')
df["date2"]=pd.to_datetime(df["date2"],format='%d-%m-%Y')
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2
# ...

# %%
df["y"]=df["date2"].dt.year
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2     y
# ...

# %%
df["M"]=df["date2"].dt.month
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2     y   M
# ...

# %%
df["md1"]=df["date1"].dt.month
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
#          date1      date2     y   M  md1
# ...

# %%
df["datename"]=df["date2"].dt.day_name()
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df["weekname"]=df["date1"].dt.day_of_week
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df["datename1"]=df["date2"].dt.day_name()
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df["month1"]=df["date2"].dt.month
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df["date1week"]=df["date2"].dt.day_of_week
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df["fgg"]=df["date1"].dt.day_name()
df
# Out:
#        id first_name    last_name                         email       gender  \
# 0       1   Lauraine      Andreia            landreia0@narod.ru       Female
# 1       2     Gannie    MacGuigan     gmacguigan1@bloglines.com         Male
# 2       3      Pippa        Boote           pboote2@comsenz.com       Female
# 3       4      Leela       Emmett            lemmett3@imgur.com       Female
# 4       5   Yovonnda        Spear               yspear4@who.int       Female
# ..    ...        ...          ...                           ...          ...
# 995   996       Ives      Stroban    istrobanrn@livejournal.com         Male
# 996   997  Ezmeralda       Radmer            eradmerro@tamu.edu       Female
# 997   998   Bethanne        Longo           blongorp@netlog.com   Polygender
# 998   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net  Genderfluid
# 999  1000     Thorin      Keitley         tkeitleyrr@oakley.com         Male
#
# ...

# %%
df=df.set_index("date2")
df
# Out:
#               id first_name    last_name                         email  \
# date2
# 2022-04-12     1   Lauraine      Andreia            landreia0@narod.ru
# 2022-06-15     2     Gannie    MacGuigan     gmacguigan1@bloglines.com
# 2022-04-09     3      Pippa        Boote           pboote2@comsenz.com
# 2022-04-11     4      Leela       Emmett            lemmett3@imgur.com
# 2022-09-28     5   Yovonnda        Spear               yspear4@who.int
# ...          ...        ...          ...                           ...
# 2022-03-26   996       Ives      Stroban    istrobanrn@livejournal.com
# 2022-04-26   997  Ezmeralda       Radmer            eradmerro@tamu.edu
# 2022-03-06   998   Bethanne        Longo           blongorp@netlog.com
# 2022-02-13   999    Darrick  Kitchingman  dkitchingmanrq@earthlink.net
# 2022-12-11  1000     Thorin      Keitley         tkeitleyrr@oakley.com
#
#                  gender      date1     y   M  md1   datename  weekname  \
# date2
# ...

# %%
df90=df.loc["2021":"2022"]
df90
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_20688\3795712783.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df90=df.loc["2021":"2022"]
#               id first_name    last_name                         email  \
# date2
# 2022-04-12     1   Lauraine      Andreia            landreia0@narod.ru
# 2022-06-15     2     Gannie    MacGuigan     gmacguigan1@bloglines.com
# 2022-04-09     3      Pippa        Boote           pboote2@comsenz.com
# 2022-04-11     4      Leela       Emmett            lemmett3@imgur.com
# 2022-09-28     5   Yovonnda        Spear               yspear4@who.int
# ...          ...        ...          ...                           ...
# 2022-03-26   996       Ives      Stroban    istrobanrn@livejournal.com
# 2022-04-26   997  Ezmeralda       Radmer            eradmerro@tamu.edu
# ...

# %%
df=df.loc["2021":"2022"]
df
# Out:
# C:\Users\nikhil pal\AppData\Local\Temp\ipykernel_20688\80186251.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df=df.loc["2021":"2022"]
#               id first_name    last_name                         email  \
# date2
# 2022-04-12     1   Lauraine      Andreia            landreia0@narod.ru
# 2022-06-15     2     Gannie    MacGuigan     gmacguigan1@bloglines.com
# 2022-04-09     3      Pippa        Boote           pboote2@comsenz.com
# 2022-04-11     4      Leela       Emmett            lemmett3@imgur.com
# 2022-09-28     5   Yovonnda        Spear               yspear4@who.int
# ...          ...        ...          ...                           ...
# 2022-03-26   996       Ives      Stroban    istrobanrn@livejournal.com
# 2022-04-26   997  Ezmeralda       Radmer            eradmerro@tamu.edu
# ...

# %% [markdown]
# # ep15

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\nikhil pal\Downloads\MOCK_DATA (6).csv")
df
# Out:
#        id first_name    last_name                           email       date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com   2/28/2022
# 1       2     Jobina      Garnall              jgarnall1@xing.com   5/13/2020
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me    2/2/2020
# 3       4     Joline        Noods                jnoods3@army.mil  11/13/2020
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com   6/29/2020
# ..    ...        ...          ...                             ...         ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp   8/21/2022
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com    1/8/2021
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com   4/10/2020
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk  11/22/2022
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com   5/24/2021
#
#             time
# ...

# %%
df["time"]=df["time"].str.replace("PM","")
df
# Out:
#        id first_name    last_name                           email       date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com   2/28/2022
# 1       2     Jobina      Garnall              jgarnall1@xing.com   5/13/2020
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me    2/2/2020
# 3       4     Joline        Noods                jnoods3@army.mil  11/13/2020
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com   6/29/2020
# ..    ...        ...          ...                             ...         ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp   8/21/2022
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com    1/8/2021
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com   4/10/2020
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk  11/22/2022
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com   5/24/2021
#
#           time
# 0    10:16:05
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   date1       1000 non-null   object
#  5   time        1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB
# None

# %%
df["date1"]=pd.to_datetime(df["date1"],format="%m-%d-%Y")
df
# Out:
#        id first_name    last_name                           email      date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com 2022-02-28
# 1       2     Jobina      Garnall              jgarnall1@xing.com 2020-05-13
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me 2020-02-02
# 3       4     Joline        Noods                jnoods3@army.mil 2020-11-13
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com 2020-06-29
# ..    ...        ...          ...                             ...        ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp 2022-08-21
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com 2021-01-08
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com 2020-04-10
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk 2022-11-22
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com 2021-05-24
#
#             time
# 0    10:16:05 PM
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   date1       1000 non-null   datetime64[ns]
#  5   time        1000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 47.0+ KB
# None

# %%
df["time"]=pd.to_datetime(df["time"])
df
# Out:
#        id first_name    last_name                           email      date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com 2022-02-28
# 1       2     Jobina      Garnall              jgarnall1@xing.com 2020-05-13
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me 2020-02-02
# 3       4     Joline        Noods                jnoods3@army.mil 2020-11-13
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com 2020-06-29
# ..    ...        ...          ...                             ...        ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp 2022-08-21
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com 2021-01-08
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com 2020-04-10
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk 2022-11-22
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com 2021-05-24
#
#                    time               time1
# ...

# %%
df["time"]=df["time"].str.replace("PM","")
df
# Out:
#        id first_name    last_name                           email       date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com   2/28/2022
# 1       2     Jobina      Garnall              jgarnall1@xing.com   5/13/2020
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me    2/2/2020
# 3       4     Joline        Noods                jnoods3@army.mil  11/13/2020
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com   6/29/2020
# ..    ...        ...          ...                             ...         ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp   8/21/2022
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com    1/8/2021
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com   4/10/2020
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk  11/22/2022
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com   5/24/2021
#
#           time
# 0    10:16:05
# ...

# %%
df
# Out:
#        id first_name    last_name                           email       date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com   2/28/2022
# 1       2     Jobina      Garnall              jgarnall1@xing.com   5/13/2020
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me    2/2/2020
# 3       4     Joline        Noods                jnoods3@army.mil  11/13/2020
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com   6/29/2020
# ..    ...        ...          ...                             ...         ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp   8/21/2022
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com    1/8/2021
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com   4/10/2020
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk  11/22/2022
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com   5/24/2021
#
#           time
# 0    10:16:05
# ...

# %%
df["date1"]=df["date1"].str.replace("/","-")
df
# Out:
#        id first_name    last_name                           email       date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com   2-28-2022
# 1       2     Jobina      Garnall              jgarnall1@xing.com   5-13-2020
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me    2-2-2020
# 3       4     Joline        Noods                jnoods3@army.mil  11-13-2020
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com   6-29-2020
# ..    ...        ...          ...                             ...         ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp   8-21-2022
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com    1-8-2021
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com   4-10-2020
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk  11-22-2022
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com   5-24-2021
#
#           time
# 0    10:16:05
# ...

# %%
df["date1"]=pd.to_datetime(df["date1"])
df
# Out:
#        id first_name    last_name                           email      date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com 2022-02-28
# 1       2     Jobina      Garnall              jgarnall1@xing.com 2020-05-13
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me 2020-02-02
# 3       4     Joline        Noods                jnoods3@army.mil 2020-11-13
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com 2020-06-29
# ..    ...        ...          ...                             ...        ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp 2022-08-21
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com 2021-01-08
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com 2020-04-10
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk 2022-11-22
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com 2021-05-24
#
#           time
# 0    10:16:05
# ...

# %%
df["date"]=df["date1"].dt.round["H"]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 df["date"]=df["date1"].dt.round["H"]
#       2 df
#
# TypeError: 'method' object is not subscriptable

# %%
df["time"]=pd.to_time(df["time"])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df["time"]=pd.to_time(df["time"])
#       2 df
#
# File ~\.conda\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_time'

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   date1       1000 non-null   datetime64[ns]
#  5   time        1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 47.0+ KB
# None

# %%
df["date1"]=df["date1"].dt.round("H")
df
# Out:
#        id first_name    last_name                           email      date1  \
# 0       1     Tommie       Derill            tderill0@smugmug.com 2022-02-28
# 1       2     Jobina      Garnall              jgarnall1@xing.com 2020-05-13
# 2       3      Jolyn     Rowthorn             jrowthorn2@about.me 2020-02-02
# 3       4     Joline        Noods                jnoods3@army.mil 2020-11-13
# 4       5      Debra       Buxcey        dbuxcey4@accuweather.com 2020-06-29
# ..    ...        ...          ...                             ...        ...
# 995   996      Patti  Rosenthaler       prosenthalerrn@dion.ne.jp 2022-08-21
# 996   997      Aleen  Cuppleditch         acuppleditchro@cnet.com 2021-01-08
# 997   998      Drona      Cropton     dcroptonrp@wunderground.com 2020-04-10
# 998   999   Meredith   De Carolis  mdecarolisrq@independent.co.uk 2022-11-22
# 999  1000      Diann       Laffin         dlaffinrr@newyorker.com 2021-05-24
#
#                    time
# ...
